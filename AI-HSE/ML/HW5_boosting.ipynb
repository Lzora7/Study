# %% [markdown]
# <a href="https://colab.research.google.com/github/Murcha1990/ML_AI24/blob/main/Hometasks/Base/AI_HW5_boosting_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Домашняя работа: прогнозирование заработной платы и кластеризация типов движений**

# %% [markdown]
# ### **Постановка задачи:**
#
# В этой работе две части:
#
# *   В первой части вам предстоит построить алгоритм на основе бустинга для прогнозирования зарплаты
# *   Во второй части вам предстоит кластеризовать типы движений по имеющимся данным с акселерометров и гироскопов
#
# ### **Оценивание:**
#
# - Как всегда оцениваются как код, так и ответы на вопросы. Если нет одного и/или другого, то часть баллов за соответствующее задание без колебаний снимается.
# - Брать код из открытых источников позволительно. Следование культуре цитирования **обязательно.**
#
# ### **Баллы:**
#
# Суммарно за задание можно получить 10 основных и 1 бонусный балл.
#
# Оценка за ДЗ = min{ваш балл, 10}
#
# **Мягкий дедлайн: 16 февраля 23:59**
#
# **Интересной вам работы!**

# %% [markdown]
# # **Часть 1. Прогнозирование заработной платы при помощи бустинга**
#
# **Количество баллов:** 7

# %% [markdown]
# ## **Постановка задачи:**
#
# Данные выгружены и лежат в файле `ds_salary.csv`. Вам доступны описания признаков и значения целевой переменной.
#
# **Ваша задача:** построение модели бустинга и оценка данной модели.
#
# ## **Описание даных**
#
# - work_year: год, в который взяты данные;
# - experience_level: уровень опыта, кодируемый как SE, MI EN или EX
# - employment_type: тип занятости (FT, PT, CT, FL)
# - job_title: название рабочей позиции в компании;
# - salary: зараплата на позиции;
# - salary_currency: валюта в которой начисляют зарплату;
# - employee_residence: страна или регион проживания сотрудника
# - remote_ratio: процент удаленки, предлагаемый в компании (0, 50, 100)
# - company_location: местоположение компании
# - company_size: размер компании, оцененный как S, M, L
# - salary_in_usd: целевая переменная

# %% [markdown]
# Как всегда, загрузим набор данных.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://github.com/hse-ds/iad-intro-ds/raw/refs/heads/master/2023/homeworks/hw-08-boosting/ds_salaries.csv")

# %%
df.to_csv('hw_5_data.csv')

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# заменил тип данных у процента удаленки на категориальный
df = df.astype({'remote_ratio': 'int32'})

# %% [markdown]
# ## **Задание 1 (0.3 балла)**
#
# Вам даны описания переменных. Проверьте, что категориальные признаки, категории которых перечислены, не имеют ошибочных значений. Для этого:
#
# - Напишите цикл, пробегающий по выбранным признакам и оценивающий, что в них нет лишних значений;

# %%
category_cols = ['experience_level', 'employment_type', 'company_size', 'remote_ratio']
values_dict = {
    'experience_level': ['SE', 'MI', 'EN', 'EX'],
    'employment_type': ['FT', 'PT', 'CT', 'FL'],
    'company_size': ['S', 'M', 'L'],
    'remote_ratio': [0, 50, 100]
}

# %%
for column in category_cols:
  for value in df[column]:
    if value not in values_dict[column]:
      print(f'в столбце {column} есть некорректное значение {value}')

# %% [markdown]
# некорректных значений нет

# %% [markdown]
# ## **Задание 2 (0.3 балла)**
#
# Проведите базовые шаги оценки качества данных.
# - Есть есть проблемы, устраните их;
# - Если нет проблем, кратко опишите это.

# %% [markdown]
# **Описательных хар-ки**

# %%
df.describe()
# данные адекватны: нет отрицательных значений, цифры соотвествуют адекватным нормам
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df.describe(include='object')
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count              3755            3755           3755            3755
# unique                4               4             93              20
# top                  SE              FT  Data Engineer             USD
# freq               2516            3718           1040            3224
#
#        employee_residence company_location company_size
# count                3755             3755         3755
# unique                 78               72            3
# top                    US               US            M
# freq                 3004             3040         3153

# %% [markdown]
# **Пропуски**

# %%
df.isna().sum()
# пропусков нет
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## **Задание 3 (0.3 балла)**
#
# Вернитесь к описанию признаков.
# - Проверьте, все ли признаки соответствуют постановке задачи? Если есть лишние признаки, удалите их и обоснуйте удаление, если нет, сделайте вывод о релевантности (достаточно в одну-две строки)
# - Зафиксируйте, в каких признаках много категорий.

# %%
# можно удалить столбец salary, так как есть в долларах
df = df.drop(columns = ['salary'])

# %%
df = df.drop(columns = ['salary_currency'])

# %% [markdown]
# **Ваши выводы здесь**

# %% [markdown]
# ## **Задание 4 (0.2 балла)**
#
# Разделите выборку на train, test (80%, 20%).

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['salary_in_usd']), df['salary_in_usd'], test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (3004, 8)

# %% [markdown]
# ## **Задание 5 (0.3 балла)**
#
# Будем проверять два сценария. Первый — построение модели только на непрерывных признаках, а второй — построение с категориальными. В этом задании подготовьте всё, чтобы проверить валидность обоих сценариев. А именно:
#
# - Выделите данные для тренировки и теста для непрерывных признаков
# - Выделите данные для тренировки и теста для непрерывных + категориальных признаков, пока ничего не кодируйте.

# %%
df.head(1)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          85847                 ES           100               ES
#
#   company_size
# 0            L

# %%
num_cols=['work_year', 'salary_in_usd']

# %%
# непрерывный признак + таргет
num_df = df[num_cols]
num_df.head(1)
# Out:
#    work_year  salary_in_usd
# 0       2023          85847

# %%
# разбиение непрерывного
X_num_train, X_num_test, y_num_train, y_num_test = train_test_split(num_df.drop(columns=['salary_in_usd']), num_df['salary_in_usd'], test_size=0.2, random_state=42)

# %% [markdown]
# ## **Задание 6 (0.2 балла)**
#
# - Обучите модель линейной регресии на числовых признаках и оцените её качество через mape и rmse;
# - Сделайте вывод о качестве построенной модели;

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
import sklearn
import numpy as np

# %%
model_lin_reg = LinearRegression()

model_lin_reg.fit(X_num_train, y_num_train)

y_pred = model_lin_reg.predict(X_num_test)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_num_test, y_pred)
# Out:
# 0.7064709508683961

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 61358.082035949934

# %% [markdown]
# **Закономерно по одному признаку качество ужасное**

# %% [markdown]
# ## **Задание 8 (0.2 балла)**
#
# - Обучите модель бустинга (любую из трех библиотек catboost, xgboost, lightgbm) с гиперпараметрами по умолчанию на непрерывных признаках и оцените её качество через mape и rmse;
# - Сделайте вывод о качестве построенной модели;

# %%
from catboost import CatBoostRegressor

# %%
model_cat_boost = CatBoostRegressor(random_seed=42, verbose=0)
model_cat_boost.fit(X_num_train, y_num_train)

y_pred = model_cat_boost.predict(X_num_test)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_num_test, y_pred)
# Out:
# 0.7065535789950731

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 61617.13415718041

# %% [markdown]
# **Очень похоже и потому также плохо**

# %% [markdown]
# ## **Задание 9 (0.8 балла)**
#
# Теперь подключим категориальные признаки. Но попроубем разные стратегии предобработки.
#
# **1:**
# - Предобработайте категориальные признаки при помощи OHE
# - Постройте модель бустинга и линейную регрессию
# - Оцените качество обеих моделей
#
# **2:**
# - Предобработайте категориальные признаки при помощи LabelEncoding
# - Постройте модель бустинга и линейную регрессию
# - Оцените качество обеих моделей
#
# **3:**
# - Предобработайте категориальные признаки при помощи MeanTargetEnc
# - Постройте модель бустинга и линейную регрессию
# - Оцените качество обеих моделей
#
# Сделайте выводы по построениям 1-3. Выберите лучшую модель и дальше поработайте с ней.

# %% [markdown]
# **1 подход**

# %%
X_categorical_cols = ['experience_level', 'employment_type', 'job_title', 'employee_residence', 'remote_ratio', 'company_location', 'company_size']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore')
encoded_categorical = encoder.fit_transform(X_train[X_categorical_cols])

encoded_categorical_df = pd.DataFrame(
    encoded_categorical,
    columns=encoder.get_feature_names_out(X_categorical_cols)
)

X_train_encoded_ohe = pd.concat([X_train['work_year'].reset_index(), encoded_categorical_df], axis=1).drop(columns=['index'])

# %%
encoded_categorical = encoder.transform(X_test[X_categorical_cols])

encoded_categorical_df = pd.DataFrame(
    encoded_categorical,
    columns=encoder.get_feature_names_out(X_categorical_cols)
)

X_test_encoded_ohe = pd.concat([X_test['work_year'].reset_index(), encoded_categorical_df], axis=1).drop(columns=['index'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [2, 3, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Бустинг
model_cat_boost = CatBoostRegressor(random_seed=42, verbose=0)
model_cat_boost.fit(X_train_encoded_ohe, y_train)

y_pred = model_cat_boost.predict(X_test_encoded_ohe)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.3634634712642949

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 48430.76138862407

# %%
# Линенйная регрессия
model_lin_reg = LinearRegression()

model_lin_reg.fit(X_train_encoded_ohe, y_train)

y_pred = model_lin_reg.predict(X_test_encoded_ohe)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.40340867305813466

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 49802.04635511091

# %% [markdown]
# **2 подход**

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_categorical_cols
# Out:
# ['experience_level',
#  'employment_type',
#  'job_title',
#  'employee_residence',
#  'remote_ratio',
#  'company_location',
#  'company_size']

# %%
# Инициализация и обучение на обучающих данных
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
ordinal_encoder.fit(X_train[X_categorical_cols])

# Преобразование обучающих и тестовых данных
encoded_labe_train = ordinal_encoder.transform(X_train[X_categorical_cols])
encoded_labe_test = ordinal_encoder.transform(X_test[X_categorical_cols])

encoded_labe_train_df = pd.DataFrame(
    encoded_labe_train,
    columns=X_categorical_cols
)

encoded_labe_test_df = pd.DataFrame(
    encoded_labe_test,
    columns=X_categorical_cols
)

X_train_encoded_labe = pd.concat([X_train['work_year'].reset_index(), encoded_labe_train_df], axis=1).drop(columns=['index'])
X_test_encoded_labe = pd.concat([X_test['work_year'].reset_index(), encoded_labe_test_df], axis=1).drop(columns=['index'])

# %%
X_train_encoded_labe.head(3)
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0       2022               3.0              2.0       31.0
# 1       2023               2.0              2.0       82.0
# 2       2022               3.0              2.0       23.0
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                24.0           0.0              23.0           1.0
# 1                71.0           2.0              66.0           1.0
# 2                71.0           0.0              66.0           1.0

# %%
# Бустинг
model_cat_boost = CatBoostRegressor(random_seed=42, verbose=0)
model_cat_boost.fit(X_train_encoded_labe, y_train)

y_pred = model_cat_boost.predict(X_test_encoded_labe)

# %%
# MAPE
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.41671354529221366

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 48835.49280449569

# %%
# Линенйная регрессия
model_lin_reg = LinearRegression()

model_lin_reg.fit(X_train_encoded_labe, y_train)

y_pred = model_lin_reg.predict(X_test_encoded_labe)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.49727770945882815

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 53263.35030903578

# %% [markdown]
# **3 подход**

# %%
from category_encoders import TargetEncoder

# %%
X_train = X_train.astype({'remote_ratio': 'object'})
X_test = X_test.astype({'remote_ratio': 'object'})

# %%
encoder = TargetEncoder()

X_train_encoded_mte_df = encoder.fit_transform(X_train[X_categorical_cols], y_train)

X_test_encoded_mte_df = encoder.transform(X_test[X_categorical_cols])

X_train_encoded_mte = pd.concat([X_train['work_year'].reset_index(), X_train_encoded_mte_df.reset_index()], axis=1).drop(columns=['index'])
X_test_encoded_mte = pd.concat([X_test['work_year'].reset_index(), X_test_encoded_mte_df.reset_index()], axis=1).drop(columns=['index'])

# %%
X_train_encoded_mte.head(3)
# Out:
#    work_year  experience_level  employment_type      job_title  \
# 0       2022     153656.470179    138820.514968  143884.887707
# 1       2023     103665.592593    138820.514968  166127.214714
# 2       2022     153656.470179    138820.514968  108194.875000
#
#    employee_residence   remote_ratio  company_location  company_size
# 0        64543.740300  144484.290046      62483.779941  143568.31458
# 1       153074.004141  137943.723596     152095.587971  143568.31458
# 2       153074.004141  144484.290046     152095.587971  143568.31458

# %%
# Бустинг
model_cat_boost = CatBoostRegressor(random_seed=42, verbose=0)
model_cat_boost.fit(X_train_encoded_mte, y_train)

y_pred = model_cat_boost.predict(X_test_encoded_mte)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.4220115835637701

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 48409.358784949545

# %%
# Линенйная регрессия
model_lin_reg = LinearRegression()

model_lin_reg.fit(X_train_encoded_mte, y_train)

y_pred = model_lin_reg.predict(X_test_encoded_mte)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.39280339583750584

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 48862.72159413691

# %% [markdown]
# Лучшей предобработкой по качеству для Бустинга стала OHE \
# Лучшей предобработкой по качеству для Линейной регрессии стала MeanTargetEncoding

# %% [markdown]
# ## **Задание 10 (0.5 балла)**
#
# Покажите, где ошибается ваша модель. Выведите топ 20 примеров с наибольшей ошибкой. Проанализируйте их. Какие выводы можно сделать? Что стоит изменить в данных чтобы улучшить качество модели?

# %%
# Линейная регрессия при MeanTargetEncoding

# абсолютная ошибка
errors = abs(y_pred - y_test)

X_test['error_model_3'] = errors

# Сортировка
X_test.sort_values(by='error_model_3', ascending=False).head(20)
# Out:
#       work_year experience_level employment_type                   job_title  \
# 1288       2023               SE              FT                Data Analyst
# 2359       2022               SE              FT      Data Science Tech Lead
# 1105       2023               SE              FT              Data Scientist
# 33         2023               SE              FT    Computer Vision Engineer
# 478        2023               EX              FT    Director of Data Science
# 1116       2023               SE              FT   Machine Learning Engineer
# 3609       2020               SE              FT  Machine Learning Scientist
# 325        2023               MI              FT   Machine Learning Engineer
# 183        2020               EX              FT          Staff Data Analyst
# 3582       2021               SE              FT          Lead Data Engineer
# 1677       2023               SE              FT              Data Scientist
# 1593       2023               SE              FT               Data Engineer
# 3387       2022               SE              FT               Data Engineer
# 358        2023               SE              FT   Machine Learning Engineer
# 254        2023               SE              FT           Research Engineer
# 1187       2023               SE              FT   Machine Learning Engineer
# 1488       2023               SE              FT              Data Scientist
# 549        2023               SE              FT              Data Scientist
# 3037       2022               SE              FT              Data Architect
# 461        2023               SE              FT              Data Scientist
#
#      employee_residence remote_ratio company_location company_size  \
# 1288                 US            0               US            M
# 2359                 US           50               US            L
# 1105                 US            0               US            M
# 33                   US            0               US            M
# 478                  US            0               US            M
# 1116                 US            0               US            M
# 3609                 JP            0               JP            S
# 325                  US          100               US            M
# 183                  NG            0               CA            M
# 3582                 US            0               US            L
# 1677                 US          100               US            M
# 1593                 US            0               US            M
# 3387                 US          100               US            M
# 358                  US          100               US            M
# 254                  US            0               US            M
# 1187                 US          100               US            M
# 1488                 US          100               US            M
# 549                  US          100               US            M
# 3037                 US            0               US            M
# 461                  CA            0               CA            M
#
#       error_model_3
# 1288  253172.874591
# 2359  230791.724941
# 1105  207481.483633
# 33    187106.961194
# 478   158114.345269
# 1116  151040.033819
# 3609  140687.210767
# 325   139110.443882
# 183   138234.580635
# 3582  136600.681491
# 1677  135347.578738
# 1593  134946.101208
# 3387  134630.676991
# 358   132306.128924
# 254   117548.342456
# 1187  116306.128924
# 1488  113347.578738
# 549   113347.578738
# 3037  112200.562569
# 461   111974.690397

# %% [markdown]
# **Ваш ответ здесь**.

# %% [markdown]
# ## **Задание 11 (0.5 балла)**
#
# Придумайте признаки для улучшения качества модели на основе предыдущего пункта. Как вам кажется какими признаками можно улучшить качетсво модели? Реализуйте признаки и проверьте улучшилось ли качество модели.
#
# **Примечание:**
# Полный балл за задание ставится даже при отсутствии улучшения качества модели, важно попробовать проверить свои гипотезы и сделать выводы.

# %% [markdown]
# Попробуем закодировать название должности по ключевым словам ANALYST, SCIENCIST, RESEARCHER, ENGINEER и т.д.

# %%
X_train_new_feature = X_train.copy()
X_test_new_feature = X_test.copy()

# %%
X_train_new_feature.head()
# Out:
#       work_year experience_level employment_type           job_title  \
# 2238       2022               SE              FT       Data Engineer
# 485        2023               MI              FT  Research Scientist
# 2177       2022               SE              FT        Data Analyst
# 3305       2022               SE              FT       Data Engineer
# 1769       2023               SE              FT       Data Engineer
#
#      employee_residence remote_ratio company_location company_size
# 2238                 ES            0               ES            M
# 485                  US          100               US            M
# 2177                 US            0               US            M
# 3305                 US          100               US            M
# 1769                 US          100               US            M

# %%
X_train_new_feature.job_title.unique()
# Out:
# array(['Data Engineer', 'Research Scientist', 'Data Analyst',
#        'Data Scientist', 'Data Science Consultant',
#        'Computer Vision Engineer', 'Machine Learning Engineer',
#        'Analytics Engineer', 'Data Architect',
#        'Applied Machine Learning Scientist',
#        'Computer Vision Software Engineer', 'Data Manager',
#        'Applied Scientist', 'Machine Learning Researcher',
#        'Business Intelligence Engineer', '3D Computer Vision Researcher',
#        'BI Developer', 'Machine Learning Developer',
#        'Cloud Database Engineer', 'Data Science Manager',
#        'Research Engineer', 'AI Scientist',
#        'Machine Learning Software Engineer', 'Machine Learning Scientist',
#        'ML Engineer', 'Business Data Analyst', 'Data Operations Engineer',
#        'Head of Machine Learning', 'AI Developer', 'NLP Engineer',
#        'Azure Data Engineer', 'BI Data Analyst', 'Big Data Engineer',
#        'Deep Learning Engineer', 'Data Quality Analyst',
#        'Principal Data Analyst', 'Head of Data Science',
#        'Lead Data Engineer', 'Machine Learning Infrastructure Engineer',
#        'Head of Data', 'Data Analytics Engineer', 'Data Science Lead',
#        'Marketing Data Analyst', 'Lead Data Scientist',
#        'Data Analytics Manager', 'Applied Data Scientist',
#        'ETL Developer', 'Marketing Data Engineer', 'Big Data Architect',
#        'Data Scientist Lead', 'BI Analyst', 'Principal Data Architect',
#        'Director of Data Science', 'Insight Analyst', 'MLOps Engineer',
#        'Data Specialist', 'Lead Machine Learning Engineer', 'Data Lead',
#        'Principal Data Scientist', 'Software Data Engineer',
#        'Lead Data Analyst', 'Data Infrastructure Engineer',
#        'Product Data Analyst', 'ETL Engineer', 'Finance Data Analyst',
#        'Data Management Specialist', 'Data Analytics Consultant',
#        'Data Modeler', 'Data Science Engineer', 'Data Analytics Lead',
#        'Data Analytics Specialist', 'Data Operations Analyst',
#        'Financial Data Analyst', 'Staff Data Scientist',
#        'Machine Learning Research Engineer',
#        'Principal Machine Learning Engineer', 'Cloud Data Architect',
#        'Applied Machine Learning Engineer', 'Compliance Data Analyst',
#        'Cloud Data Engineer', 'Principal Data Engineer',
#        'Manager Data Management', 'Data DevOps Engineer',
#        'Machine Learning Manager', 'BI Data Engineer'], dtype=object)

# %% [markdown]
# Флаги будем ставить для следующих слов: Analyst, Scientist, Engineer, Researcher, Developer, BI

# %%
words_to_find = ['Analyst', 'Scientist', 'Engineer', 'Researcher', 'Developer', 'BI', 'Manager', 'Architect']

# %%
def categorize_job_name(row):
    found_words = [word for word in words_to_find if word in row]
    if len(found_words) == 0:
        return 'unknown'
    else:
        return found_words[0]

# %%
X_train_new_feature['name_job_category'] = X_train_new_feature['job_title'].apply(categorize_job_name)
X_test_new_feature['name_job_category'] = X_test_new_feature['job_title'].apply(categorize_job_name)

# %%
X_train_new_feature.head()
# Out:
#       work_year experience_level employment_type           job_title  \
# 2238       2022               SE              FT       Data Engineer
# 485        2023               MI              FT  Research Scientist
# 2177       2022               SE              FT        Data Analyst
# 3305       2022               SE              FT       Data Engineer
# 1769       2023               SE              FT       Data Engineer
#
#      employee_residence remote_ratio company_location company_size  \
# 2238                 ES            0               ES            M
# 485                  US          100               US            M
# 2177                 US            0               US            M
# 3305                 US          100               US            M
# 1769                 US          100               US            M
#
#      name_job_category
# 2238          Engineer
# 485          Scientist
# 2177           Analyst
# 3305          Engineer
# 1769          Engineer

# %%
X_train_new_feature.query('name_job_category == "unknown"')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 2115       2022               MI              FT   Data Science Consultant
# 3192       2022               EX              FT  Head of Machine Learning
# 812        2023               MI              FT   Data Science Consultant
# 3311       2022               EX              FT      Head of Data Science
# 3436       2021               SE              FT              Head of Data
# ...         ...              ...             ...                       ...
# 2572       2022               SE              FT         Data Science Lead
# 3561       2021               EN              FT   Data Science Consultant
# 2747       2022               EN              FT           Data Specialist
# 3444       2022               MI              FT              Head of Data
# 3092       2022               SE              FT           Data Specialist
#
#      employee_residence remote_ratio company_location company_size  \
# 2115                 GB            0               GB            M
# 3192                 IN           50               IN            L
# 812                  US            0               US            M
# 3311                 US          100               US            M
# 3436                 SI          100               SI            L
# ...                 ...          ...              ...          ...
# 2572                 US           50               US            S
# 3561                 DE          100               DE            S
# 2747                 CL          100               US            L
# 3444                 EE          100               EE            S
# 3092                 US          100               US            L
#
#      name_job_category
# 2115           unknown
# 3192           unknown
# 812            unknown
# 3311           unknown
# 3436           unknown
# ...                ...
# 2572           unknown
# 3561           unknown
# 2747           unknown
# 3444           unknown
# 3092           unknown
#
# [72 rows x 9 columns]

# %%
X_categorical_cols_new_feat = X_categorical_cols.copy()
X_categorical_cols_new_feat.append('name_job_category')
X_categorical_cols_new_feat
# Out:
# ['experience_level',
#  'employment_type',
#  'job_title',
#  'employee_residence',
#  'remote_ratio',
#  'company_location',
#  'company_size',
#  'name_job_category']

# %%
# Применим TargetEncoding
X_categorical_cols_new_feat = X_categorical_cols.copy()
X_categorical_cols_new_feat.append(words_to_find)


encoder_new_feat = TargetEncoder()

X_train_new_feat_encoded_mte_df = encoder_new_feat.fit_transform(X_train_new_feature[['experience_level', 'employment_type', 'employee_residence', 'remote_ratio',
 'company_location',
 'company_size',
 'name_job_category']], y_train)

X_test_new_feat_encoded_mte_df = encoder_new_feat.transform(X_test_new_feature[['experience_level', 'employment_type', 'employee_residence', 'remote_ratio',
 'company_location',
 'company_size',
 'name_job_category']])

X_train_new_feat_encoded_mte = pd.concat([X_train['work_year'].reset_index(), X_train_new_feat_encoded_mte_df.reset_index()], axis=1).drop(columns=['index'])
X_test_new_feat_encoded_mte = pd.concat([X_test['work_year'].reset_index(), X_test_new_feat_encoded_mte_df.reset_index()], axis=1).drop(columns=['index'])

# %%
# Обучим
# Бустинг
model_cat_boost = CatBoostRegressor(random_seed=42, verbose=0)
model_cat_boost.fit(X_train_new_feat_encoded_mte, y_train)

y_pred = model_cat_boost.predict(X_test_new_feat_encoded_mte)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.443605945120783

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 49986.628376879686

# %%
# Линенйная регрессия
model_lin_reg = LinearRegression()

model_lin_reg.fit(X_train_new_feat_encoded_mte, y_train)

y_pred = model_lin_reg.predict(X_test_new_feat_encoded_mte)

# %%
# MAPE
sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.3989138663440934

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 49331.029655736966

# %% [markdown]
# **Качество стало чуть хуже, но сам признак стал значительно проще - вместо целого названия должности теперь одна из 9 категорий**.

# %% [markdown]
# ## **Задание 12 (1 балл)**
#
# Поупражняемся с разными бустингами!
#
# - Используйте catboost.
# - Обучите модель — на полном наборе данных с категориальными признаками.
# - Подберите оптимальные гиперпараметры.
# - Оцените качество итоговой модели, скорость обучения и скорость предсказания.
#
#
# **Примечание:**
# Замерять скорость = смотреть, как долго исполняется код.

# %%
from catboost import CatBoostRegressor, Pool, cv
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import time

# %%
# Pool для CatBoost
train_pool = Pool(X_train_encoded_mte, y_train)
test_pool = Pool(X_test_encoded_mte, y_test)

# CatBoostRegressor
cbr = CatBoostRegressor(
    iterations=1000,  # Количество итераций
    learning_rate=0.1,  # Скорость обучения
    depth=6,  # Глубина дерева
    loss_function='RMSE',  # Функция потерь
    eval_metric='RMSE',  # Метрика для оценки
    random_seed=42,
    verbose=100  # Вывод лога каждые 100 итераций
)

# время обучения
start_time = time.time()
cbr.fit(train_pool)
training_time = time.time() - start_time
print(f"Время обучения: {training_time:.2f} секунд")

# время обучения
start_time = time.time()
y_pred = cbr.predict(test_pool)
prediction_time = time.time() - start_time
print(f"Время предсказания: {prediction_time:.2f} секунд")

# качество модели
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Среднеквадратичная ошибка (MSE): {mse:.4f}")
print(f"Коэффициент детерминации (R^2): {r2:.4f}")

# Подбор
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.1, 0.2],
    'iterations': [500, 1000, 1500]
}

grid_search = GridSearchCV(estimator=cbr, 
                           param_grid=param_grid, 
                           cv=3, 
                           scoring='neg_mean_squared_error')

# время поиска гиперпараметров
start_time = time.time()
grid_search.fit(X_train_encoded_mte, y_train)
grid_search_time = time.time() - start_time
print(f"Время подбора гиперпараметров: {grid_search_time:.2f} секунд")

# Лучшие параметры
print("Лучшие параметры:", grid_search.best_params_)

# качество модели с лучшими параметрами
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(test_pool)
rmse_best = (mean_squared_error(y_test, y_pred_best))**0.5
r2_best = r2_score(y_test, y_pred_best)
print(f"Среднеквадратичная ошибка (RMSE) с лучшими параметрами: {rmse_best:.4f}")
print(f"Коэффициент детерминации (R^2) с лучшими параметрами: {r2_best:.4f}")
# Out:
# 0:	learn: 60716.0443475	total: 719us	remaining: 719ms
# 100:	learn: 44441.1242864	total: 45.4ms	remaining: 405ms
# 200:	learn: 42804.7035662	total: 90.8ms	remaining: 361ms
# 300:	learn: 41913.7171109	total: 135ms	remaining: 314ms
# 400:	learn: 41346.1683077	total: 181ms	remaining: 270ms
# 500:	learn: 40990.8258277	total: 226ms	remaining: 225ms
# 600:	learn: 40726.1371822	total: 270ms	remaining: 179ms
# 700:	learn: 40535.6327130	total: 315ms	remaining: 134ms
# 800:	learn: 40370.2297733	total: 358ms	remaining: 88.9ms
# 900:	learn: 40249.6584406	total: 400ms	remaining: 43.9ms
# 999:	learn: 40162.3263316	total: 442ms	remaining: 0us
# Время обучения: 0.47 секунд
# Время предсказания: 0.00 секунд
# Среднеквадратичная ошибка (MSE): 2436599538.9318
# Коэффициент детерминации (R^2): 0.3828
# 0:	learn: 62843.5525790	total: 208us	remaining: 104ms
# 100:	learn: 50613.9199242	total: 25.8ms	remaining: 102ms
# 200:	learn: 47552.3192757	total: 51.3ms	remaining: 76.4ms
# 300:	learn: 46482.6681368	total: 76.1ms	remaining: 50.3ms
# 400:	learn: 45923.3132876	total: 102ms	remaining: 25.2ms
# 499:	learn: 45555.3140420	total: 127ms	remaining: 0us
# 0:	learn: 62784.9205310	total: 275us	remaining: 137ms
# 100:	learn: 50996.0157543	total: 26.4ms	remaining: 104ms
# 200:	learn: 48017.6326996	total: 52.2ms	remaining: 77.6ms
# 300:	learn: 46987.3264779	total: 76.3ms	remaining: 50.4ms
# 400:	learn: 46493.5267895	total: 101ms	remaining: 25ms
# 499:	learn: 46144.5782157	total: 126ms	remaining: 0us
# 0:	learn: 62935.6003692	total: 243us	remaining: 122ms
# 100:	learn: 52542.7098854	total: 25.7ms	remaining: 101ms
# 200:	learn: 49836.3137510	total: 51.1ms	remaining: 76.1ms
# 300:	learn: 48918.7424730	total: 75.2ms	remaining: 49.7ms
# 400:	learn: 48409.3208319	total: 98.5ms	remaining: 24.3ms
# 499:	learn: 48066.8779459	total: 122ms	remaining: 0us
# 0:	learn: 60707.1469361	total: 242us	remaining: 121ms
# 100:	learn: 44075.9213980	total: 26ms	remaining: 103ms
# 200:	learn: 42530.5912521	total: 53.1ms	remaining: 79ms
# 300:	learn: 41743.7679363	total: 78.9ms	remaining: 52.2ms
# 400:	learn: 41293.2547586	total: 104ms	remaining: 25.6ms
# 499:	learn: 40931.2385224	total: 127ms	remaining: 0us
# 0:	learn: 60727.8494328	total: 276us	remaining: 138ms
# 100:	learn: 44922.5310549	total: 24.1ms	remaining: 95.2ms
# 200:	learn: 43428.6582945	total: 47.4ms	remaining: 70.5ms
# 300:	learn: 42602.2303043	total: 72.2ms	remaining: 47.7ms
# 400:	learn: 42023.1004551	total: 98.1ms	remaining: 24.2ms
# 499:	learn: 41641.8582943	total: 121ms	remaining: 0us
# 0:	learn: 61132.9036344	total: 327us	remaining: 164ms
# 100:	learn: 46776.4315256	total: 24.9ms	remaining: 98.2ms
# 200:	learn: 44965.6927591	total: 48.6ms	remaining: 72.3ms
# 300:	learn: 43971.7163424	total: 74ms	remaining: 48.9ms
# 400:	learn: 43291.7859966	total: 97.9ms	remaining: 24.2ms
# 499:	learn: 42763.9689469	total: 123ms	remaining: 0us
# 0:	learn: 58483.9895447	total: 1.01ms	remaining: 507ms
# 100:	learn: 42538.3106990	total: 27ms	remaining: 107ms
# 200:	learn: 41275.1281799	total: 51.6ms	remaining: 76.7ms
# 300:	learn: 40610.4496722	total: 76.1ms	remaining: 50.3ms
# 400:	learn: 40193.7189452	total: 100ms	remaining: 24.8ms
# 499:	learn: 39896.8390610	total: 124ms	remaining: 0us
# 0:	learn: 58590.1785819	total: 244us	remaining: 122ms
# 100:	learn: 43559.6606664	total: 25.3ms	remaining: 100ms
# 200:	learn: 42083.7243914	total: 50.1ms	remaining: 74.6ms
# 300:	learn: 41331.7426952	total: 77.2ms	remaining: 51.1ms
# 400:	learn: 40865.5738283	total: 102ms	remaining: 25.1ms
# 499:	learn: 40573.0740860	total: 125ms	remaining: 0us
# 0:	learn: 59268.5641604	total: 935us	remaining: 467ms
# 100:	learn: 44771.1617464	total: 24.6ms	remaining: 97ms
# 200:	learn: 43276.3447886	total: 51.4ms	remaining: 76.5ms
# 300:	learn: 42439.6751026	total: 75.8ms	remaining: 50.1ms
# 400:	learn: 41863.5253309	total: 99.7ms	remaining: 24.6ms
# 499:	learn: 41552.4193588	total: 124ms	remaining: 0us
# 0:	learn: 62843.5525790	total: 276us	remaining: 277ms
# 100:	learn: 50613.9199242	total: 25.3ms	remaining: 225ms
# 200:	learn: 47552.3192757	total: 50.6ms	remaining: 201ms
# 300:	learn: 46482.6681368	total: 76.9ms	remaining: 179ms
# 400:	learn: 45923.3132876	total: 103ms	remaining: 153ms
# 500:	learn: 45550.9726271	total: 127ms	remaining: 127ms
# 600:	learn: 45229.2713257	total: 153ms	remaining: 102ms
# 700:	learn: 44958.2048065	total: 177ms	remaining: 75.4ms
# 800:	learn: 44695.5304477	total: 201ms	remaining: 50ms
# 900:	learn: 44420.1950510	total: 227ms	remaining: 24.9ms
# 999:	learn: 44154.4429299	total: 251ms	remaining: 0us
# 0:	learn: 62784.9205310	total: 254us	remaining: 254ms
# 100:	learn: 50996.0157543	total: 25.5ms	remaining: 227ms
# 200:	learn: 48017.6326996	total: 49.8ms	remaining: 198ms
# 300:	learn: 46987.3264779	total: 73.5ms	remaining: 171ms
# 400:	learn: 46493.5267895	total: 97.9ms	remaining: 146ms
# 500:	learn: 46143.7130523	total: 123ms	remaining: 123ms
# 600:	learn: 45876.3551373	total: 147ms	remaining: 97.9ms
# 700:	learn: 45628.8329667	total: 173ms	remaining: 73.7ms
# 800:	learn: 45405.8379598	total: 197ms	remaining: 49ms
# 900:	learn: 45200.9187977	total: 221ms	remaining: 24.3ms
# 999:	learn: 45002.0392119	total: 246ms	remaining: 0us
# 0:	learn: 62935.6003692	total: 212us	remaining: 212ms
# 100:	learn: 52542.7098854	total: 24.5ms	remaining: 218ms
# 200:	learn: 49836.3137510	total: 51.6ms	remaining: 205ms
# 300:	learn: 48918.7424730	total: 75.5ms	remaining: 175ms
# 400:	learn: 48409.3208319	total: 99.2ms	remaining: 148ms
# 500:	learn: 48063.7775816	total: 124ms	remaining: 124ms
# 600:	learn: 47768.5208511	total: 150ms	remaining: 99.7ms
# 700:	learn: 47519.4767379	total: 175ms	remaining: 74.5ms
# 800:	learn: 47265.1326761	total: 201ms	remaining: 49.9ms
# 900:	learn: 47016.1466291	total: 225ms	remaining: 24.7ms
# 999:	learn: 46808.9019643	total: 250ms	remaining: 0us
# 0:	learn: 60707.1469361	total: 215us	remaining: 215ms
# 100:	learn: 44075.9213980	total: 24.3ms	remaining: 216ms
# 200:	learn: 42530.5912521	total: 51.6ms	remaining: 205ms
# 300:	learn: 41743.7679363	total: 77.7ms	remaining: 181ms
# 400:	learn: 41293.2547586	total: 103ms	remaining: 153ms
# 500:	learn: 40929.6140464	total: 127ms	remaining: 127ms
# 600:	learn: 40671.2616906	total: 154ms	remaining: 102ms
# 700:	learn: 40458.5849771	total: 178ms	remaining: 76.1ms
# 800:	learn: 40264.3209458	total: 204ms	remaining: 50.8ms
# 900:	learn: 40117.9455942	total: 229ms	remaining: 25.2ms
# 999:	learn: 39993.8395173	total: 254ms	remaining: 0us
# 0:	learn: 60727.8494328	total: 216us	remaining: 217ms
# 100:	learn: 44922.5310549	total: 24.2ms	remaining: 216ms
# 200:	learn: 43428.6582945	total: 48.8ms	remaining: 194ms
# 300:	learn: 42602.2303043	total: 72.1ms	remaining: 167ms
# 400:	learn: 42023.1004551	total: 96ms	remaining: 143ms
# 500:	learn: 41638.3527810	total: 120ms	remaining: 120ms
# 600:	learn: 41319.7398626	total: 145ms	remaining: 96.5ms
# 700:	learn: 41069.4125864	total: 171ms	remaining: 73.1ms
# 800:	learn: 40859.7923416	total: 195ms	remaining: 48.5ms
# 900:	learn: 40693.9597951	total: 218ms	remaining: 24ms
# 999:	learn: 40558.9764180	total: 243ms	remaining: 0us
# 0:	learn: 61132.9036344	total: 1.05ms	remaining: 1.04s
# 100:	learn: 46776.4315256	total: 25ms	remaining: 223ms
# 200:	learn: 44965.6927591	total: 49.9ms	remaining: 198ms
# 300:	learn: 43971.7163424	total: 75.2ms	remaining: 175ms
# 400:	learn: 43291.7859966	total: 99.7ms	remaining: 149ms
# 500:	learn: 42758.9103204	total: 124ms	remaining: 124ms
# 600:	learn: 42349.7111971	total: 148ms	remaining: 98.5ms
# 700:	learn: 42093.7873892	total: 173ms	remaining: 73.7ms
# 800:	learn: 41873.4892427	total: 197ms	remaining: 48.9ms
# 900:	learn: 41698.2993206	total: 223ms	remaining: 24.6ms
# 999:	learn: 41564.5846070	total: 247ms	remaining: 0us
# 0:	learn: 58483.9895447	total: 226us	remaining: 227ms
# 100:	learn: 42538.3106990	total: 26.5ms	remaining: 236ms
# 200:	learn: 41275.1281799	total: 52.9ms	remaining: 210ms
# 300:	learn: 40610.4496722	total: 77.2ms	remaining: 179ms
# 400:	learn: 40193.7189452	total: 102ms	remaining: 152ms
# 500:	learn: 39895.7645933	total: 128ms	remaining: 128ms
# 600:	learn: 39689.2189692	total: 156ms	remaining: 104ms
# 700:	learn: 39496.3595151	total: 181ms	remaining: 77.3ms
# 800:	learn: 39368.0947425	total: 205ms	remaining: 51ms
# 900:	learn: 39253.0660410	total: 230ms	remaining: 25.3ms
# 999:	learn: 39145.1606992	total: 254ms	remaining: 0us
# 0:	learn: 58590.1785819	total: 974us	remaining: 973ms
# 100:	learn: 43559.6606664	total: 26.3ms	remaining: 234ms
# 200:	learn: 42083.7243914	total: 52.6ms	remaining: 209ms
# 300:	learn: 41331.7426952	total: 77.4ms	remaining: 180ms
# 400:	learn: 40865.5738283	total: 102ms	remaining: 152ms
# 500:	learn: 40568.8494822	total: 125ms	remaining: 125ms
# 600:	learn: 40365.3970828	total: 150ms	remaining: 99.3ms
# 700:	learn: 40241.8206088	total: 173ms	remaining: 73.8ms
# 800:	learn: 40076.9039813	total: 198ms	remaining: 49.2ms
# 900:	learn: 39956.3025465	total: 222ms	remaining: 24.4ms
# 999:	learn: 39848.1558073	total: 245ms	remaining: 0us
# 0:	learn: 59268.5641604	total: 369us	remaining: 369ms
# 100:	learn: 44771.1617464	total: 24.9ms	remaining: 222ms
# 200:	learn: 43276.3447886	total: 49.4ms	remaining: 196ms
# 300:	learn: 42439.6751026	total: 74.1ms	remaining: 172ms
# 400:	learn: 41863.5253309	total: 98.1ms	remaining: 147ms
# 500:	learn: 41548.5798398	total: 121ms	remaining: 121ms
# 600:	learn: 41301.8180761	total: 145ms	remaining: 96.4ms
# 700:	learn: 41151.6073100	total: 170ms	remaining: 72.7ms
# 800:	learn: 41037.2832235	total: 194ms	remaining: 48.3ms
# 900:	learn: 40928.3225259	total: 217ms	remaining: 23.9ms
# 999:	learn: 40832.2563785	total: 241ms	remaining: 0us
# 0:	learn: 62843.5525790	total: 292us	remaining: 439ms
# 100:	learn: 50613.9199242	total: 27.4ms	remaining: 379ms
# 200:	learn: 47552.3192757	total: 51.3ms	remaining: 331ms
# 300:	learn: 46482.6681368	total: 75.8ms	remaining: 302ms
# 400:	learn: 45923.3132876	total: 99.8ms	remaining: 273ms
# 500:	learn: 45550.9726271	total: 125ms	remaining: 248ms
# 600:	learn: 45229.2713257	total: 149ms	remaining: 223ms
# 700:	learn: 44958.2048065	total: 173ms	remaining: 198ms
# 800:	learn: 44695.5304477	total: 200ms	remaining: 174ms
# 900:	learn: 44420.1950510	total: 224ms	remaining: 149ms
# 1000:	learn: 44151.7520192	total: 249ms	remaining: 124ms
# 1100:	learn: 43922.1483100	total: 274ms	remaining: 99.4ms
# 1200:	learn: 43714.8556515	total: 299ms	remaining: 74.3ms
# 1300:	learn: 43532.3752104	total: 324ms	remaining: 49.6ms
# 1400:	learn: 43368.4718415	total: 348ms	remaining: 24.6ms
# 1499:	learn: 43221.5149946	total: 373ms	remaining: 0us
# 0:	learn: 62784.9205310	total: 988us	remaining: 1.48s
# 100:	learn: 50996.0157543	total: 26.2ms	remaining: 363ms
# 200:	learn: 48017.6326996	total: 50.5ms	remaining: 326ms
# 300:	learn: 46987.3264779	total: 74.3ms	remaining: 296ms
# 400:	learn: 46493.5267895	total: 98.4ms	remaining: 270ms
# 500:	learn: 46143.7130523	total: 123ms	remaining: 246ms
# 600:	learn: 45876.3551373	total: 147ms	remaining: 220ms
# 700:	learn: 45628.8329667	total: 171ms	remaining: 194ms
# 800:	learn: 45405.8379598	total: 196ms	remaining: 171ms
# 900:	learn: 45200.9187977	total: 221ms	remaining: 147ms
# 1000:	learn: 45000.0859991	total: 246ms	remaining: 123ms
# 1100:	learn: 44830.2441845	total: 271ms	remaining: 98.1ms
# 1200:	learn: 44676.5798778	total: 294ms	remaining: 73.3ms
# 1300:	learn: 44493.5521148	total: 317ms	remaining: 48.6ms
# 1400:	learn: 44317.0468163	total: 343ms	remaining: 24.2ms
# 1499:	learn: 44165.4342947	total: 366ms	remaining: 0us
# 0:	learn: 62935.6003692	total: 201us	remaining: 301ms
# 100:	learn: 52542.7098854	total: 24.8ms	remaining: 344ms
# 200:	learn: 49836.3137510	total: 49.5ms	remaining: 320ms
# 300:	learn: 48918.7424730	total: 73.7ms	remaining: 294ms
# 400:	learn: 48409.3208319	total: 99.3ms	remaining: 272ms
# 500:	learn: 48063.7775816	total: 123ms	remaining: 246ms
# 600:	learn: 47768.5208511	total: 147ms	remaining: 219ms
# 700:	learn: 47519.4767379	total: 170ms	remaining: 194ms
# 800:	learn: 47265.1326761	total: 194ms	remaining: 170ms
# 900:	learn: 47016.1466291	total: 219ms	remaining: 145ms
# 1000:	learn: 46807.6935408	total: 243ms	remaining: 121ms
# 1100:	learn: 46576.4544380	total: 267ms	remaining: 96.7ms
# 1200:	learn: 46338.3684188	total: 293ms	remaining: 72.8ms
# 1300:	learn: 46105.4828289	total: 316ms	remaining: 48.4ms
# 1400:	learn: 45900.4892746	total: 343ms	remaining: 24.2ms
# 1499:	learn: 45696.6287066	total: 368ms	remaining: 0us
# 0:	learn: 60707.1469361	total: 218us	remaining: 328ms
# 100:	learn: 44075.9213980	total: 25.3ms	remaining: 350ms
# 200:	learn: 42530.5912521	total: 48.8ms	remaining: 315ms
# 300:	learn: 41743.7679363	total: 74.2ms	remaining: 296ms
# 400:	learn: 41293.2547586	total: 98.7ms	remaining: 271ms
# 500:	learn: 40929.6140464	total: 125ms	remaining: 249ms
# 600:	learn: 40671.2616906	total: 150ms	remaining: 224ms
# 700:	learn: 40458.5849771	total: 174ms	remaining: 199ms
# 800:	learn: 40264.3209458	total: 200ms	remaining: 175ms
# 900:	learn: 40117.9455942	total: 227ms	remaining: 151ms
# 1000:	learn: 39992.5718478	total: 252ms	remaining: 126ms
# 1100:	learn: 39863.8189175	total: 275ms	remaining: 99.8ms
# 1200:	learn: 39751.6562073	total: 299ms	remaining: 74.5ms
# 1300:	learn: 39655.2179378	total: 324ms	remaining: 49.5ms
# 1400:	learn: 39579.9941225	total: 349ms	remaining: 24.7ms
# 1499:	learn: 39512.2140575	total: 373ms	remaining: 0us
# 0:	learn: 60727.8494328	total: 234us	remaining: 351ms
# 100:	learn: 44922.5310549	total: 26.6ms	remaining: 368ms
# 200:	learn: 43428.6582945	total: 50.9ms	remaining: 329ms
# 300:	learn: 42602.2303043	total: 77.5ms	remaining: 309ms
# 400:	learn: 42023.1004551	total: 101ms	remaining: 277ms
# 500:	learn: 41638.3527810	total: 126ms	remaining: 252ms
# 600:	learn: 41319.7398626	total: 152ms	remaining: 227ms
# 700:	learn: 41069.4125864	total: 175ms	remaining: 200ms
# 800:	learn: 40859.7923416	total: 200ms	remaining: 175ms
# 900:	learn: 40693.9597951	total: 225ms	remaining: 150ms
# 1000:	learn: 40558.5223577	total: 250ms	remaining: 124ms
# 1100:	learn: 40449.7271206	total: 274ms	remaining: 99.2ms
# 1200:	learn: 40350.9560614	total: 297ms	remaining: 74ms
# 1300:	learn: 40274.2126805	total: 323ms	remaining: 49.4ms
# 1400:	learn: 40203.8217295	total: 347ms	remaining: 24.5ms
# 1499:	learn: 40134.8359429	total: 371ms	remaining: 0us
# 0:	learn: 61132.9036344	total: 207us	remaining: 311ms
# 100:	learn: 46776.4315256	total: 24.7ms	remaining: 342ms
# 200:	learn: 44965.6927591	total: 49.6ms	remaining: 320ms
# 300:	learn: 43971.7163424	total: 74.7ms	remaining: 298ms
# 400:	learn: 43291.7859966	total: 98.6ms	remaining: 270ms
# 500:	learn: 42758.9103204	total: 123ms	remaining: 245ms
# 600:	learn: 42349.7111971	total: 147ms	remaining: 220ms
# 700:	learn: 42093.7873892	total: 173ms	remaining: 197ms
# 800:	learn: 41873.4892427	total: 197ms	remaining: 172ms
# 900:	learn: 41698.2993206	total: 223ms	remaining: 148ms
# 1000:	learn: 41563.8951881	total: 248ms	remaining: 124ms
# 1100:	learn: 41440.4825102	total: 272ms	remaining: 98.7ms
# 1200:	learn: 41348.0903810	total: 295ms	remaining: 73.6ms
# 1300:	learn: 41247.5584970	total: 319ms	remaining: 48.8ms
# 1400:	learn: 41162.2187819	total: 344ms	remaining: 24.3ms
# 1499:	learn: 41091.3223581	total: 368ms	remaining: 0us
# 0:	learn: 58483.9895447	total: 270us	remaining: 405ms
# 100:	learn: 42538.3106990	total: 25.9ms	remaining: 359ms
# 200:	learn: 41275.1281799	total: 51.3ms	remaining: 332ms
# 300:	learn: 40610.4496722	total: 76.7ms	remaining: 305ms
# 400:	learn: 40193.7189452	total: 102ms	remaining: 279ms
# 500:	learn: 39895.7645933	total: 125ms	remaining: 250ms
# 600:	learn: 39689.2189692	total: 151ms	remaining: 226ms
# 700:	learn: 39496.3595151	total: 174ms	remaining: 199ms
# 800:	learn: 39368.0947425	total: 199ms	remaining: 174ms
# 900:	learn: 39253.0660410	total: 222ms	remaining: 148ms
# 1000:	learn: 39144.2276324	total: 246ms	remaining: 123ms
# 1100:	learn: 39043.1583438	total: 271ms	remaining: 98.2ms
# 1200:	learn: 38977.3700935	total: 297ms	remaining: 73.8ms
# 1300:	learn: 38902.0280225	total: 322ms	remaining: 49.2ms
# 1400:	learn: 38860.2996561	total: 348ms	remaining: 24.6ms
# 1499:	learn: 38805.5870344	total: 374ms	remaining: 0us
# 0:	learn: 58590.1785819	total: 248us	remaining: 373ms
# 100:	learn: 43559.6606664	total: 26ms	remaining: 360ms
# 200:	learn: 42083.7243914	total: 50.9ms	remaining: 329ms
# 300:	learn: 41331.7426952	total: 77.3ms	remaining: 308ms
# 400:	learn: 40865.5738283	total: 101ms	remaining: 277ms
# 500:	learn: 40568.8494822	total: 126ms	remaining: 251ms
# 600:	learn: 40365.3970828	total: 150ms	remaining: 225ms
# 700:	learn: 40241.8206088	total: 174ms	remaining: 198ms
# 800:	learn: 40076.9039813	total: 200ms	remaining: 175ms
# 900:	learn: 39956.3025465	total: 227ms	remaining: 151ms
# 1000:	learn: 39848.0417968	total: 252ms	remaining: 126ms
# 1100:	learn: 39758.9676712	total: 278ms	remaining: 101ms
# 1200:	learn: 39685.0094643	total: 301ms	remaining: 74.9ms
# 1300:	learn: 39624.1057989	total: 327ms	remaining: 50ms
# 1400:	learn: 39567.0362209	total: 351ms	remaining: 24.8ms
# 1499:	learn: 39519.8307583	total: 376ms	remaining: 0us
# 0:	learn: 59268.5641604	total: 273us	remaining: 410ms
# 100:	learn: 44771.1617464	total: 25.8ms	remaining: 358ms
# 200:	learn: 43276.3447886	total: 51.4ms	remaining: 332ms
# 300:	learn: 42439.6751026	total: 77.1ms	remaining: 307ms
# 400:	learn: 41863.5253309	total: 101ms	remaining: 278ms
# 500:	learn: 41548.5798398	total: 126ms	remaining: 251ms
# 600:	learn: 41301.8180761	total: 150ms	remaining: 225ms
# 700:	learn: 41151.6073100	total: 175ms	remaining: 199ms
# 800:	learn: 41037.2832235	total: 199ms	remaining: 174ms
# 900:	learn: 40928.3225259	total: 225ms	remaining: 150ms
# 1000:	learn: 40831.1515650	total: 249ms	remaining: 124ms
# 1100:	learn: 40735.9256987	total: 273ms	remaining: 99.1ms
# 1200:	learn: 40668.3861838	total: 298ms	remaining: 74.2ms
# 1300:	learn: 40605.8359430	total: 322ms	remaining: 49.2ms
# 1400:	learn: 40562.0249336	total: 346ms	remaining: 24.5ms
# 1499:	learn: 40521.0474213	total: 372ms	remaining: 0us
# 0:	learn: 62859.4761916	total: 401us	remaining: 200ms
# 100:	learn: 50068.9886638	total: 33.2ms	remaining: 131ms
# 200:	learn: 46747.5528491	total: 68.8ms	remaining: 102ms
# 300:	learn: 45604.1856274	total: 102ms	remaining: 67.6ms
# 400:	learn: 44968.0666489	total: 137ms	remaining: 33.7ms
# 499:	learn: 44499.4461881	total: 170ms	remaining: 0us
# 0:	learn: 62796.4618538	total: 1.09ms	remaining: 542ms
# 100:	learn: 50471.7224659	total: 36.8ms	remaining: 145ms
# 200:	learn: 47213.0225956	total: 73.4ms	remaining: 109ms
# 300:	learn: 46073.4334842	total: 106ms	remaining: 70ms
# 400:	learn: 45503.2176700	total: 139ms	remaining: 34.4ms
# 499:	learn: 45092.2239863	total: 173ms	remaining: 0us
# 0:	learn: 62944.7608132	total: 416us	remaining: 208ms
# 100:	learn: 51969.4488092	total: 33.8ms	remaining: 134ms
# 200:	learn: 49005.8081109	total: 66.7ms	remaining: 99.3ms
# 300:	learn: 47923.1162811	total: 101ms	remaining: 66.7ms
# 400:	learn: 47321.8588766	total: 134ms	remaining: 33ms
# 499:	learn: 46917.3747537	total: 167ms	remaining: 0us
# 0:	learn: 60857.7140971	total: 349us	remaining: 174ms
# 100:	learn: 42820.3081933	total: 34.1ms	remaining: 135ms
# 200:	learn: 41023.8368808	total: 68.6ms	remaining: 102ms
# 300:	learn: 40207.1439122	total: 104ms	remaining: 68.9ms
# 400:	learn: 39701.6125901	total: 140ms	remaining: 34.6ms
# 499:	learn: 39352.5139028	total: 174ms	remaining: 0us
# 0:	learn: 60835.0509356	total: 364us	remaining: 182ms
# 100:	learn: 43725.5248761	total: 34.6ms	remaining: 137ms
# 200:	learn: 42045.5177857	total: 68.4ms	remaining: 102ms
# 300:	learn: 41003.6980828	total: 102ms	remaining: 67.5ms
# 400:	learn: 40352.1975010	total: 138ms	remaining: 34ms
# 499:	learn: 39968.9145796	total: 171ms	remaining: 0us
# 0:	learn: 61216.7443582	total: 394us	remaining: 197ms
# 100:	learn: 45170.4253408	total: 35.1ms	remaining: 138ms
# 200:	learn: 43122.0408228	total: 68.8ms	remaining: 102ms
# 300:	learn: 42068.6431132	total: 104ms	remaining: 68.6ms
# 400:	learn: 41513.6841216	total: 137ms	remaining: 33.8ms
# 499:	learn: 41163.1085046	total: 171ms	remaining: 0us
# 0:	learn: 58763.7489401	total: 1.11ms	remaining: 554ms
# 100:	learn: 40993.3411163	total: 37.3ms	remaining: 148ms
# 200:	learn: 39690.3086147	total: 72.4ms	remaining: 108ms
# 300:	learn: 39089.6281918	total: 110ms	remaining: 72.5ms
# 400:	learn: 38740.4030478	total: 146ms	remaining: 36ms
# 499:	learn: 38466.5181091	total: 180ms	remaining: 0us
# 0:	learn: 58784.5517723	total: 338us	remaining: 169ms
# 100:	learn: 41889.2127095	total: 34.6ms	remaining: 137ms
# 200:	learn: 40346.5802900	total: 69.7ms	remaining: 104ms
# 300:	learn: 39747.7704207	total: 106ms	remaining: 69.8ms
# 400:	learn: 39400.6940159	total: 139ms	remaining: 34.3ms
# 499:	learn: 39228.1497657	total: 173ms	remaining: 0us
# 0:	learn: 59417.5804758	total: 347us	remaining: 173ms
# 100:	learn: 43006.5410585	total: 36ms	remaining: 142ms
# 200:	learn: 41497.5018169	total: 71.6ms	remaining: 106ms
# 300:	learn: 40867.8996743	total: 106ms	remaining: 69.8ms
# 400:	learn: 40555.9118854	total: 139ms	remaining: 34.3ms
# 499:	learn: 40344.6125603	total: 172ms	remaining: 0us
# 0:	learn: 62859.4761916	total: 343us	remaining: 343ms
# 100:	learn: 50068.9886638	total: 33.8ms	remaining: 301ms
# 200:	learn: 46747.5528491	total: 67.8ms	remaining: 270ms
# 300:	learn: 45604.1856274	total: 102ms	remaining: 237ms
# 400:	learn: 44968.0666489	total: 138ms	remaining: 206ms
# 500:	learn: 44496.9705158	total: 174ms	remaining: 173ms
# 600:	learn: 44119.2413516	total: 207ms	remaining: 138ms
# 700:	learn: 43801.6604910	total: 242ms	remaining: 103ms
# 800:	learn: 43490.1680206	total: 277ms	remaining: 68.9ms
# 900:	learn: 43141.1354527	total: 313ms	remaining: 34.4ms
# 999:	learn: 42832.1254222	total: 348ms	remaining: 0us
# 0:	learn: 62796.4618538	total: 473us	remaining: 473ms
# 100:	learn: 50471.7224659	total: 36.9ms	remaining: 329ms
# 200:	learn: 47213.0225956	total: 70.3ms	remaining: 279ms
# 300:	learn: 46073.4334842	total: 104ms	remaining: 242ms
# 400:	learn: 45503.2176700	total: 137ms	remaining: 205ms
# 500:	learn: 45089.6757253	total: 172ms	remaining: 171ms
# 600:	learn: 44773.3313163	total: 205ms	remaining: 136ms
# 700:	learn: 44508.8980151	total: 241ms	remaining: 103ms
# 800:	learn: 44245.0337122	total: 274ms	remaining: 68.2ms
# 900:	learn: 43975.9649172	total: 307ms	remaining: 33.7ms
# 999:	learn: 43697.4201065	total: 341ms	remaining: 0us
# 0:	learn: 62944.7608132	total: 327us	remaining: 327ms
# 100:	learn: 51969.4488092	total: 34.4ms	remaining: 306ms
# 200:	learn: 49005.8081109	total: 67.4ms	remaining: 268ms
# 300:	learn: 47923.1162811	total: 104ms	remaining: 242ms
# 400:	learn: 47321.8588766	total: 138ms	remaining: 206ms
# 500:	learn: 46912.9833777	total: 169ms	remaining: 168ms
# 600:	learn: 46540.7704995	total: 201ms	remaining: 133ms
# 700:	learn: 46204.0620566	total: 233ms	remaining: 99.5ms
# 800:	learn: 45896.0439979	total: 268ms	remaining: 66.6ms
# 900:	learn: 45568.2513557	total: 300ms	remaining: 33ms
# 999:	learn: 45271.2755798	total: 333ms	remaining: 0us
# 0:	learn: 60857.7140971	total: 381us	remaining: 381ms
# 100:	learn: 42820.3081933	total: 35ms	remaining: 312ms
# 200:	learn: 41023.8368808	total: 72.1ms	remaining: 286ms
# 300:	learn: 40207.1439122	total: 107ms	remaining: 248ms
# 400:	learn: 39701.6125901	total: 142ms	remaining: 212ms
# 500:	learn: 39348.5989705	total: 177ms	remaining: 176ms
# 600:	learn: 39078.2817457	total: 210ms	remaining: 140ms
# 700:	learn: 38878.2869870	total: 245ms	remaining: 105ms
# 800:	learn: 38742.9417331	total: 281ms	remaining: 69.8ms
# 900:	learn: 38625.9120497	total: 315ms	remaining: 34.6ms
# 999:	learn: 38507.5129885	total: 348ms	remaining: 0us
# 0:	learn: 60835.0509356	total: 295us	remaining: 295ms
# 100:	learn: 43725.5248761	total: 36.6ms	remaining: 326ms
# 200:	learn: 42045.5177857	total: 69.1ms	remaining: 275ms
# 300:	learn: 41003.6980828	total: 103ms	remaining: 239ms
# 400:	learn: 40352.1975010	total: 139ms	remaining: 208ms
# 500:	learn: 39966.6471565	total: 174ms	remaining: 174ms
# 600:	learn: 39729.0716318	total: 209ms	remaining: 139ms
# 700:	learn: 39558.4700319	total: 242ms	remaining: 103ms
# 800:	learn: 39405.3291958	total: 276ms	remaining: 68.6ms
# 900:	learn: 39294.0698109	total: 309ms	remaining: 33.9ms
# 999:	learn: 39213.7663905	total: 341ms	remaining: 0us
# 0:	learn: 61216.7443582	total: 304us	remaining: 305ms
# 100:	learn: 45170.4253408	total: 34.1ms	remaining: 304ms
# 200:	learn: 43122.0408228	total: 69.3ms	remaining: 275ms
# 300:	learn: 42068.6431132	total: 104ms	remaining: 241ms
# 400:	learn: 41513.6841216	total: 139ms	remaining: 208ms
# 500:	learn: 41162.0048449	total: 171ms	remaining: 171ms
# 600:	learn: 40907.5727272	total: 204ms	remaining: 136ms
# 700:	learn: 40711.6083727	total: 238ms	remaining: 102ms
# 800:	learn: 40559.0523005	total: 270ms	remaining: 67.2ms
# 900:	learn: 40460.4995509	total: 305ms	remaining: 33.5ms
# 999:	learn: 40368.4966705	total: 339ms	remaining: 0us
# 0:	learn: 58763.7489401	total: 482us	remaining: 482ms
# 100:	learn: 40993.3411163	total: 35.5ms	remaining: 316ms
# 200:	learn: 39690.3086147	total: 71.4ms	remaining: 284ms
# 300:	learn: 39089.6281918	total: 106ms	remaining: 247ms
# 400:	learn: 38740.4030478	total: 141ms	remaining: 211ms
# 500:	learn: 38466.0115497	total: 176ms	remaining: 176ms
# 600:	learn: 38315.1043956	total: 210ms	remaining: 139ms
# 700:	learn: 38203.5078263	total: 244ms	remaining: 104ms
# 800:	learn: 38113.2204461	total: 278ms	remaining: 69.2ms
# 900:	learn: 38065.4347684	total: 312ms	remaining: 34.3ms
# 999:	learn: 38016.6570465	total: 347ms	remaining: 0us
# 0:	learn: 58784.5517723	total: 351us	remaining: 351ms
# 100:	learn: 41889.2127095	total: 35ms	remaining: 312ms
# 200:	learn: 40346.5802900	total: 67.4ms	remaining: 268ms
# 300:	learn: 39747.7704207	total: 101ms	remaining: 235ms
# 400:	learn: 39400.6940159	total: 136ms	remaining: 203ms
# 500:	learn: 39219.9501988	total: 170ms	remaining: 169ms
# 600:	learn: 39096.1348178	total: 202ms	remaining: 134ms
# 700:	learn: 38994.1131939	total: 236ms	remaining: 101ms
# 800:	learn: 38922.8839067	total: 271ms	remaining: 67.3ms
# 900:	learn: 38865.9397150	total: 303ms	remaining: 33.3ms
# 999:	learn: 38823.0681846	total: 336ms	remaining: 0us
# 0:	learn: 59417.5804758	total: 446us	remaining: 446ms
# 100:	learn: 43006.5410585	total: 35.2ms	remaining: 313ms
# 200:	learn: 41497.5018169	total: 69ms	remaining: 274ms
# 300:	learn: 40867.8996743	total: 103ms	remaining: 239ms
# 400:	learn: 40555.9118854	total: 137ms	remaining: 205ms
# 500:	learn: 40344.1020911	total: 170ms	remaining: 169ms
# 600:	learn: 40215.9290420	total: 205ms	remaining: 136ms
# 700:	learn: 40132.2350839	total: 238ms	remaining: 102ms
# 800:	learn: 40068.6112235	total: 273ms	remaining: 67.8ms
# 900:	learn: 40018.9133375	total: 305ms	remaining: 33.6ms
# 999:	learn: 39980.7781109	total: 338ms	remaining: 0us
# 0:	learn: 62859.4761916	total: 314us	remaining: 472ms
# 100:	learn: 50068.9886638	total: 33.4ms	remaining: 463ms
# 200:	learn: 46747.5528491	total: 65.5ms	remaining: 423ms
# 300:	learn: 45604.1856274	total: 100ms	remaining: 400ms
# 400:	learn: 44968.0666489	total: 134ms	remaining: 367ms
# 500:	learn: 44496.9705158	total: 166ms	remaining: 331ms
# 600:	learn: 44119.2413516	total: 201ms	remaining: 301ms
# 700:	learn: 43801.6604910	total: 234ms	remaining: 267ms
# 800:	learn: 43490.1680206	total: 268ms	remaining: 234ms
# 900:	learn: 43141.1354527	total: 303ms	remaining: 201ms
# 1000:	learn: 42830.3145762	total: 338ms	remaining: 168ms
# 1100:	learn: 42544.7707056	total: 371ms	remaining: 134ms
# 1200:	learn: 42320.6301618	total: 405ms	remaining: 101ms
# 1300:	learn: 42114.8120948	total: 441ms	remaining: 67.4ms
# 1400:	learn: 41935.2800022	total: 477ms	remaining: 33.7ms
# 1499:	learn: 41756.2677566	total: 513ms	remaining: 0us
# 0:	learn: 62796.4618538	total: 283us	remaining: 425ms
# 100:	learn: 50471.7224659	total: 35.9ms	remaining: 497ms
# 200:	learn: 47213.0225956	total: 69.7ms	remaining: 450ms
# 300:	learn: 46073.4334842	total: 103ms	remaining: 412ms
# 400:	learn: 45503.2176700	total: 137ms	remaining: 376ms
# 500:	learn: 45089.6757253	total: 169ms	remaining: 338ms
# 600:	learn: 44773.3313163	total: 203ms	remaining: 303ms
# 700:	learn: 44508.8980151	total: 240ms	remaining: 273ms
# 800:	learn: 44245.0337122	total: 275ms	remaining: 240ms
# 900:	learn: 43975.9649172	total: 307ms	remaining: 204ms
# 1000:	learn: 43695.1982081	total: 339ms	remaining: 169ms
# 1100:	learn: 43451.1311619	total: 373ms	remaining: 135ms
# 1200:	learn: 43237.0899803	total: 407ms	remaining: 101ms
# 1300:	learn: 43044.6840453	total: 440ms	remaining: 67.3ms
# 1400:	learn: 42849.0229045	total: 473ms	remaining: 33.4ms
# 1499:	learn: 42657.8153599	total: 507ms	remaining: 0us
# 0:	learn: 62944.7608132	total: 363us	remaining: 545ms
# 100:	learn: 51969.4488092	total: 33.4ms	remaining: 462ms
# 200:	learn: 49005.8081109	total: 67.8ms	remaining: 438ms
# 300:	learn: 47923.1162811	total: 101ms	remaining: 401ms
# 400:	learn: 47321.8588766	total: 135ms	remaining: 369ms
# 500:	learn: 46912.9833777	total: 169ms	remaining: 337ms
# 600:	learn: 46540.7704995	total: 203ms	remaining: 303ms
# 700:	learn: 46204.0620566	total: 235ms	remaining: 268ms
# 800:	learn: 45896.0439979	total: 268ms	remaining: 234ms
# 900:	learn: 45568.2513557	total: 301ms	remaining: 200ms
# 1000:	learn: 45269.0404219	total: 335ms	remaining: 167ms
# 1100:	learn: 44977.2819481	total: 368ms	remaining: 133ms
# 1200:	learn: 44703.2798596	total: 405ms	remaining: 101ms
# 1300:	learn: 44455.5912267	total: 438ms	remaining: 67ms
# 1400:	learn: 44203.7571988	total: 473ms	remaining: 33.4ms
# 1499:	learn: 43990.1853198	total: 507ms	remaining: 0us
# 0:	learn: 60857.7140971	total: 1.01ms	remaining: 1.52s
# 100:	learn: 42820.3081933	total: 35.3ms	remaining: 489ms
# 200:	learn: 41023.8368808	total: 69.1ms	remaining: 447ms
# 300:	learn: 40207.1439122	total: 107ms	remaining: 426ms
# 400:	learn: 39701.6125901	total: 141ms	remaining: 386ms
# 500:	learn: 39348.5989705	total: 176ms	remaining: 350ms
# 600:	learn: 39078.2817457	total: 211ms	remaining: 316ms
# 700:	learn: 38878.2869870	total: 247ms	remaining: 281ms
# 800:	learn: 38742.9417331	total: 282ms	remaining: 246ms
# 900:	learn: 38625.9120497	total: 316ms	remaining: 210ms
# 1000:	learn: 38507.0430044	total: 350ms	remaining: 174ms
# 1100:	learn: 38408.9991921	total: 387ms	remaining: 140ms
# 1200:	learn: 38336.9927195	total: 420ms	remaining: 105ms
# 1300:	learn: 38278.1958975	total: 455ms	remaining: 69.6ms
# 1400:	learn: 38213.2143715	total: 488ms	remaining: 34.5ms
# 1499:	learn: 38168.6109597	total: 523ms	remaining: 0us
# 0:	learn: 60835.0509356	total: 339us	remaining: 508ms
# 100:	learn: 43725.5248761	total: 33.9ms	remaining: 469ms
# 200:	learn: 42045.5177857	total: 68ms	remaining: 440ms
# 300:	learn: 41003.6980828	total: 101ms	remaining: 402ms
# 400:	learn: 40352.1975010	total: 135ms	remaining: 370ms
# 500:	learn: 39966.6471565	total: 169ms	remaining: 338ms
# 600:	learn: 39729.0716318	total: 204ms	remaining: 304ms
# 700:	learn: 39558.4700319	total: 238ms	remaining: 272ms
# 800:	learn: 39405.3291958	total: 276ms	remaining: 240ms
# 900:	learn: 39294.0698109	total: 308ms	remaining: 205ms
# 1000:	learn: 39212.0719216	total: 344ms	remaining: 172ms
# 1100:	learn: 39142.1069603	total: 381ms	remaining: 138ms
# 1200:	learn: 39081.9461513	total: 415ms	remaining: 103ms
# 1300:	learn: 39033.2162730	total: 450ms	remaining: 68.9ms
# 1400:	learn: 38986.7425093	total: 486ms	remaining: 34.4ms
# 1499:	learn: 38948.2165844	total: 518ms	remaining: 0us
# 0:	learn: 61216.7443582	total: 1.05ms	remaining: 1.57s
# 100:	learn: 45170.4253408	total: 35.7ms	remaining: 495ms
# 200:	learn: 43122.0408228	total: 67.9ms	remaining: 439ms
# 300:	learn: 42068.6431132	total: 101ms	remaining: 401ms
# 400:	learn: 41513.6841216	total: 134ms	remaining: 367ms
# 500:	learn: 41162.0048449	total: 169ms	remaining: 336ms
# 600:	learn: 40907.5727272	total: 203ms	remaining: 304ms
# 700:	learn: 40711.6083727	total: 237ms	remaining: 270ms
# 800:	learn: 40559.0523005	total: 271ms	remaining: 237ms
# 900:	learn: 40460.4995509	total: 306ms	remaining: 203ms
# 1000:	learn: 40368.3417908	total: 339ms	remaining: 169ms
# 1100:	learn: 40295.2351253	total: 372ms	remaining: 135ms
# 1200:	learn: 40219.4400281	total: 406ms	remaining: 101ms
# 1300:	learn: 40170.6368963	total: 452ms	remaining: 69.1ms
# 1400:	learn: 40127.1599540	total: 486ms	remaining: 34.3ms
# 1499:	learn: 40091.4843225	total: 520ms	remaining: 0us
# 0:	learn: 58763.7489401	total: 388us	remaining: 582ms
# 100:	learn: 40993.3411163	total: 38.8ms	remaining: 537ms
# 200:	learn: 39690.3086147	total: 75.9ms	remaining: 490ms
# 300:	learn: 39089.6281918	total: 110ms	remaining: 437ms
# 400:	learn: 38740.4030478	total: 144ms	remaining: 395ms
# 500:	learn: 38466.0115497	total: 178ms	remaining: 356ms
# 600:	learn: 38315.1043956	total: 215ms	remaining: 322ms
# 700:	learn: 38203.5078263	total: 251ms	remaining: 286ms
# 800:	learn: 38113.2204461	total: 286ms	remaining: 250ms
# 900:	learn: 38065.4347684	total: 322ms	remaining: 214ms
# 1000:	learn: 38016.5690617	total: 359ms	remaining: 179ms
# 1100:	learn: 37983.5706184	total: 393ms	remaining: 142ms
# 1200:	learn: 37951.3646322	total: 427ms	remaining: 106ms
# 1300:	learn: 37929.8910774	total: 459ms	remaining: 70.2ms
# 1400:	learn: 37911.5330191	total: 491ms	remaining: 34.7ms
# 1499:	learn: 37899.4284414	total: 524ms	remaining: 0us
# 0:	learn: 58784.5517723	total: 985us	remaining: 1.48s
# 100:	learn: 41889.2127095	total: 35.8ms	remaining: 496ms
# 200:	learn: 40346.5802900	total: 70.8ms	remaining: 457ms
# 300:	learn: 39747.7704207	total: 108ms	remaining: 431ms
# 400:	learn: 39400.6940159	total: 144ms	remaining: 395ms
# 500:	learn: 39219.9501988	total: 178ms	remaining: 355ms
# 600:	learn: 39096.1348178	total: 212ms	remaining: 318ms
# 700:	learn: 38994.1131939	total: 247ms	remaining: 282ms
# 800:	learn: 38922.8839067	total: 282ms	remaining: 246ms
# 900:	learn: 38865.9397150	total: 317ms	remaining: 211ms
# 1000:	learn: 38822.7533770	total: 351ms	remaining: 175ms
# 1100:	learn: 38790.0047728	total: 385ms	remaining: 139ms
# 1200:	learn: 38759.0993369	total: 418ms	remaining: 104ms
# 1300:	learn: 38736.1011357	total: 453ms	remaining: 69.3ms
# 1400:	learn: 38719.0514938	total: 488ms	remaining: 34.5ms
# 1499:	learn: 38702.5153147	total: 521ms	remaining: 0us
# 0:	learn: 59417.5804758	total: 402us	remaining: 603ms
# 100:	learn: 43006.5410585	total: 34.2ms	remaining: 474ms
# 200:	learn: 41497.5018169	total: 67.5ms	remaining: 436ms
# 300:	learn: 40867.8996743	total: 103ms	remaining: 411ms
# 400:	learn: 40555.9118854	total: 138ms	remaining: 378ms
# 500:	learn: 40344.1020911	total: 173ms	remaining: 344ms
# 600:	learn: 40215.9290420	total: 207ms	remaining: 310ms
# 700:	learn: 40132.2350839	total: 242ms	remaining: 276ms
# 800:	learn: 40068.6112235	total: 275ms	remaining: 240ms
# 900:	learn: 40018.9133375	total: 308ms	remaining: 205ms
# 1000:	learn: 39980.6826442	total: 343ms	remaining: 171ms
# 1100:	learn: 39951.2082653	total: 377ms	remaining: 137ms
# 1200:	learn: 39930.2025538	total: 410ms	remaining: 102ms
# 1300:	learn: 39907.3670681	total: 444ms	remaining: 68ms
# 1400:	learn: 39887.9882902	total: 478ms	remaining: 33.8ms
# 1499:	learn: 39873.0446227	total: 514ms	remaining: 0us
# 0:	learn: 62860.1318252	total: 575us	remaining: 287ms
# 100:	learn: 49824.8842753	total: 47.7ms	remaining: 189ms
# 200:	learn: 46271.5751430	total: 97.4ms	remaining: 145ms
# 300:	learn: 44919.3452421	total: 145ms	remaining: 96.2ms
# 400:	learn: 44192.6505455	total: 194ms	remaining: 47.9ms
# 499:	learn: 43686.0658558	total: 241ms	remaining: 0us
# 0:	learn: 62798.9965915	total: 603us	remaining: 301ms
# 100:	learn: 50171.1192779	total: 50.3ms	remaining: 199ms
# 200:	learn: 46705.6515225	total: 97.4ms	remaining: 145ms
# 300:	learn: 45369.9564620	total: 148ms	remaining: 97.9ms
# 400:	learn: 44664.9816762	total: 194ms	remaining: 48ms
# 499:	learn: 44246.0757511	total: 240ms	remaining: 0us
# 0:	learn: 62944.5397044	total: 531us	remaining: 265ms
# 100:	learn: 51620.5773970	total: 49ms	remaining: 194ms
# 200:	learn: 48452.1370957	total: 98.5ms	remaining: 146ms
# 300:	learn: 47129.7111385	total: 146ms	remaining: 96.6ms
# 400:	learn: 46400.6540287	total: 192ms	remaining: 47.3ms
# 499:	learn: 45885.9319327	total: 237ms	remaining: 0us
# 0:	learn: 60860.6403080	total: 452us	remaining: 226ms
# 100:	learn: 41703.5108081	total: 49.2ms	remaining: 194ms
# 200:	learn: 39830.6260317	total: 98.8ms	remaining: 147ms
# 300:	learn: 39061.4808293	total: 147ms	remaining: 97.5ms
# 400:	learn: 38638.9064526	total: 199ms	remaining: 49.1ms
# 499:	learn: 38389.2958396	total: 248ms	remaining: 0us
# 0:	learn: 60856.8258042	total: 535us	remaining: 267ms
# 100:	learn: 42674.0184305	total: 47.9ms	remaining: 189ms
# 200:	learn: 40685.2972010	total: 98.6ms	remaining: 147ms
# 300:	learn: 39837.3304986	total: 149ms	remaining: 98.7ms
# 400:	learn: 39410.9382545	total: 199ms	remaining: 49.2ms
# 499:	learn: 39158.5762438	total: 248ms	remaining: 0us
# 0:	learn: 61211.6218274	total: 456us	remaining: 228ms
# 100:	learn: 44044.2997614	total: 47.4ms	remaining: 187ms
# 200:	learn: 41841.9251419	total: 95.1ms	remaining: 142ms
# 300:	learn: 41005.5174595	total: 144ms	remaining: 95.4ms
# 400:	learn: 40564.9855984	total: 193ms	remaining: 47.7ms
# 499:	learn: 40336.5540934	total: 242ms	remaining: 0us
# 0:	learn: 58760.9593574	total: 572us	remaining: 286ms
# 100:	learn: 39842.6796612	total: 52.2ms	remaining: 206ms
# 200:	learn: 38685.5856301	total: 104ms	remaining: 155ms
# 300:	learn: 38247.3674481	total: 154ms	remaining: 102ms
# 400:	learn: 38054.8167762	total: 202ms	remaining: 49.8ms
# 499:	learn: 37958.7083840	total: 251ms	remaining: 0us
# 0:	learn: 58819.5307400	total: 558us	remaining: 279ms
# 100:	learn: 40569.1702244	total: 51.9ms	remaining: 205ms
# 200:	learn: 39331.4368333	total: 103ms	remaining: 153ms
# 300:	learn: 38961.3580353	total: 151ms	remaining: 100ms
# 400:	learn: 38811.8424306	total: 204ms	remaining: 50.3ms
# 499:	learn: 38731.2763125	total: 253ms	remaining: 0us
# 0:	learn: 59400.5007808	total: 479us	remaining: 239ms
# 100:	learn: 41846.9043244	total: 48ms	remaining: 190ms
# 200:	learn: 40587.9742082	total: 97.6ms	remaining: 145ms
# 300:	learn: 40173.6086206	total: 147ms	remaining: 97ms
# 400:	learn: 40008.0206695	total: 194ms	remaining: 48ms
# 499:	learn: 39917.7840586	total: 243ms	remaining: 0us
# 0:	learn: 62860.1318252	total: 515us	remaining: 515ms
# 100:	learn: 49824.8842753	total: 45.6ms	remaining: 406ms
# 200:	learn: 46271.5751430	total: 92.6ms	remaining: 368ms
# 300:	learn: 44919.3452421	total: 143ms	remaining: 331ms
# 400:	learn: 44192.6505455	total: 188ms	remaining: 281ms
# 500:	learn: 43680.2507804	total: 233ms	remaining: 232ms
# 600:	learn: 43249.8957759	total: 279ms	remaining: 185ms
# 700:	learn: 42881.1715531	total: 329ms	remaining: 141ms
# 800:	learn: 42499.1987321	total: 379ms	remaining: 94.3ms
# 900:	learn: 42135.3143604	total: 429ms	remaining: 47.1ms
# 999:	learn: 41778.9893571	total: 479ms	remaining: 0us
# 0:	learn: 62798.9965915	total: 1.77ms	remaining: 1.77s
# 100:	learn: 50171.1192779	total: 48.9ms	remaining: 435ms
# 200:	learn: 46705.6515225	total: 99.9ms	remaining: 397ms
# 300:	learn: 45369.9564620	total: 152ms	remaining: 353ms
# 400:	learn: 44664.9816762	total: 201ms	remaining: 300ms
# 500:	learn: 44242.2889724	total: 246ms	remaining: 245ms
# 600:	learn: 43889.9675226	total: 294ms	remaining: 195ms
# 700:	learn: 43591.8954353	total: 341ms	remaining: 145ms
# 800:	learn: 43275.8139766	total: 387ms	remaining: 96.1ms
# 900:	learn: 42959.4553296	total: 436ms	remaining: 47.9ms
# 999:	learn: 42621.1000497	total: 490ms	remaining: 0us
# 0:	learn: 62944.5397044	total: 682us	remaining: 682ms
# 100:	learn: 51620.5773970	total: 52.7ms	remaining: 469ms
# 200:	learn: 48452.1370957	total: 103ms	remaining: 410ms
# 300:	learn: 47129.7111385	total: 151ms	remaining: 350ms
# 400:	learn: 46400.6540287	total: 197ms	remaining: 294ms
# 500:	learn: 45884.3244022	total: 242ms	remaining: 242ms
# 600:	learn: 45472.9907775	total: 291ms	remaining: 193ms
# 700:	learn: 45121.1539318	total: 355ms	remaining: 151ms
# 800:	learn: 44735.4843049	total: 404ms	remaining: 100ms
# 900:	learn: 44356.6500839	total: 451ms	remaining: 49.5ms
# 999:	learn: 44010.9747764	total: 499ms	remaining: 0us
# 0:	learn: 60860.6403080	total: 670us	remaining: 670ms
# 100:	learn: 41703.5108081	total: 52.6ms	remaining: 469ms
# 200:	learn: 39830.6260317	total: 107ms	remaining: 426ms
# 300:	learn: 39061.4808293	total: 158ms	remaining: 367ms
# 400:	learn: 38638.9064526	total: 209ms	remaining: 312ms
# 500:	learn: 38388.4674151	total: 259ms	remaining: 258ms
# 600:	learn: 38214.4822194	total: 312ms	remaining: 207ms
# 700:	learn: 38106.5115334	total: 379ms	remaining: 162ms
# 800:	learn: 38031.4147518	total: 433ms	remaining: 107ms
# 900:	learn: 37983.4475734	total: 482ms	remaining: 52.9ms
# 999:	learn: 37944.2813980	total: 534ms	remaining: 0us
# 0:	learn: 60856.8258042	total: 1.22ms	remaining: 1.22s
# 100:	learn: 42674.0184305	total: 53.1ms	remaining: 473ms
# 200:	learn: 40685.2972010	total: 106ms	remaining: 419ms
# 300:	learn: 39837.3304986	total: 155ms	remaining: 359ms
# 400:	learn: 39410.9382545	total: 205ms	remaining: 307ms
# 500:	learn: 39156.3274479	total: 258ms	remaining: 257ms
# 600:	learn: 39010.6995349	total: 313ms	remaining: 208ms
# 700:	learn: 38908.8669330	total: 381ms	remaining: 163ms
# 800:	learn: 38848.0882015	total: 434ms	remaining: 108ms
# 900:	learn: 38797.1689391	total: 485ms	remaining: 53.3ms
# 999:	learn: 38759.9443297	total: 537ms	remaining: 0us
# 0:	learn: 61211.6218274	total: 628us	remaining: 628ms
# 100:	learn: 44044.2997614	total: 49ms	remaining: 436ms
# 200:	learn: 41841.9251419	total: 102ms	remaining: 404ms
# 300:	learn: 41005.5174595	total: 154ms	remaining: 359ms
# 400:	learn: 40564.9855984	total: 203ms	remaining: 303ms
# 500:	learn: 40333.7573423	total: 256ms	remaining: 255ms
# 600:	learn: 40183.7577049	total: 312ms	remaining: 207ms
# 700:	learn: 40080.3325238	total: 368ms	remaining: 157ms
# 800:	learn: 40011.5266767	total: 419ms	remaining: 104ms
# 900:	learn: 39960.6698535	total: 469ms	remaining: 51.5ms
# 999:	learn: 39920.6828668	total: 521ms	remaining: 0us
# 0:	learn: 58760.9593574	total: 608us	remaining: 608ms
# 100:	learn: 39842.6796612	total: 55ms	remaining: 489ms
# 200:	learn: 38685.5856301	total: 122ms	remaining: 486ms
# 300:	learn: 38247.3674481	total: 176ms	remaining: 408ms
# 400:	learn: 38054.8167762	total: 229ms	remaining: 342ms
# 500:	learn: 37957.9510278	total: 279ms	remaining: 278ms
# 600:	learn: 37896.8087266	total: 336ms	remaining: 223ms
# 700:	learn: 37865.8959941	total: 386ms	remaining: 165ms
# 800:	learn: 37846.4957854	total: 438ms	remaining: 109ms
# 900:	learn: 37835.5327105	total: 488ms	remaining: 53.6ms
# 999:	learn: 37828.7952225	total: 543ms	remaining: 0us
# 0:	learn: 58819.5307400	total: 1.35ms	remaining: 1.34s
# 100:	learn: 40569.1702244	total: 56.2ms	remaining: 500ms
# 200:	learn: 39331.4368333	total: 107ms	remaining: 425ms
# 300:	learn: 38961.3580353	total: 156ms	remaining: 363ms
# 400:	learn: 38811.8424306	total: 207ms	remaining: 310ms
# 500:	learn: 38730.4561790	total: 261ms	remaining: 260ms
# 600:	learn: 38685.6673446	total: 314ms	remaining: 209ms
# 700:	learn: 38660.2361816	total: 365ms	remaining: 156ms
# 800:	learn: 38646.6488834	total: 414ms	remaining: 103ms
# 900:	learn: 38636.5476166	total: 466ms	remaining: 51.2ms
# 999:	learn: 38629.1089512	total: 517ms	remaining: 0us
# 0:	learn: 59400.5007808	total: 574us	remaining: 574ms
# 100:	learn: 41846.9043244	total: 47.8ms	remaining: 426ms
# 200:	learn: 40587.9742082	total: 96.6ms	remaining: 384ms
# 300:	learn: 40173.6086206	total: 145ms	remaining: 337ms
# 400:	learn: 40008.0206695	total: 195ms	remaining: 291ms
# 500:	learn: 39917.7002463	total: 245ms	remaining: 244ms
# 600:	learn: 39871.3249153	total: 294ms	remaining: 195ms
# 700:	learn: 39840.4144452	total: 346ms	remaining: 148ms
# 800:	learn: 39823.9329423	total: 414ms	remaining: 103ms
# 900:	learn: 39812.6806227	total: 465ms	remaining: 51.1ms
# 999:	learn: 39805.6099724	total: 514ms	remaining: 0us
# 0:	learn: 62860.1318252	total: 454us	remaining: 682ms
# 100:	learn: 49824.8842753	total: 47.8ms	remaining: 663ms
# 200:	learn: 46271.5751430	total: 94.9ms	remaining: 613ms
# 300:	learn: 44919.3452421	total: 143ms	remaining: 568ms
# 400:	learn: 44192.6505455	total: 191ms	remaining: 523ms
# 500:	learn: 43680.2507804	total: 236ms	remaining: 471ms
# 600:	learn: 43249.8957759	total: 283ms	remaining: 423ms
# 700:	learn: 42881.1715531	total: 332ms	remaining: 378ms
# 800:	learn: 42499.1987321	total: 380ms	remaining: 331ms
# 900:	learn: 42135.3143604	total: 429ms	remaining: 285ms
# 1000:	learn: 41776.6387618	total: 479ms	remaining: 239ms
# 1100:	learn: 41463.8801983	total: 528ms	remaining: 191ms
# 1200:	learn: 41191.6801921	total: 577ms	remaining: 144ms
# 1300:	learn: 40955.4180147	total: 627ms	remaining: 95.9ms
# 1400:	learn: 40765.5417820	total: 678ms	remaining: 47.9ms
# 1499:	learn: 40581.5069402	total: 729ms	remaining: 0us
# 0:	learn: 62798.9965915	total: 515us	remaining: 773ms
# 100:	learn: 50171.1192779	total: 49ms	remaining: 678ms
# 200:	learn: 46705.6515225	total: 97.6ms	remaining: 631ms
# 300:	learn: 45369.9564620	total: 149ms	remaining: 593ms
# 400:	learn: 44664.9816762	total: 197ms	remaining: 540ms
# 500:	learn: 44242.2889724	total: 241ms	remaining: 481ms
# 600:	learn: 43889.9675226	total: 286ms	remaining: 428ms
# 700:	learn: 43591.8954353	total: 332ms	remaining: 378ms
# 800:	learn: 43275.8139766	total: 380ms	remaining: 331ms
# 900:	learn: 42959.4553296	total: 428ms	remaining: 284ms
# 1000:	learn: 42617.3022031	total: 475ms	remaining: 237ms
# 1100:	learn: 42339.0063853	total: 523ms	remaining: 190ms
# 1200:	learn: 42080.1480541	total: 571ms	remaining: 142ms
# 1300:	learn: 41845.7746987	total: 619ms	remaining: 94.7ms
# 1400:	learn: 41618.5537423	total: 669ms	remaining: 47.3ms
# 1499:	learn: 41419.6131466	total: 718ms	remaining: 0us
# 0:	learn: 62944.5397044	total: 531us	remaining: 797ms
# 100:	learn: 51620.5773970	total: 48.8ms	remaining: 675ms
# 200:	learn: 48452.1370957	total: 98.1ms	remaining: 634ms
# 300:	learn: 47129.7111385	total: 145ms	remaining: 580ms
# 400:	learn: 46400.6540287	total: 190ms	remaining: 522ms
# 500:	learn: 45884.3244022	total: 237ms	remaining: 473ms
# 600:	learn: 45472.9907775	total: 282ms	remaining: 421ms
# 700:	learn: 45121.1539318	total: 326ms	remaining: 372ms
# 800:	learn: 44735.4843049	total: 375ms	remaining: 327ms
# 900:	learn: 44356.6500839	total: 425ms	remaining: 283ms
# 1000:	learn: 44006.4929638	total: 476ms	remaining: 237ms
# 1100:	learn: 43689.7316623	total: 524ms	remaining: 190ms
# 1200:	learn: 43407.4269581	total: 575ms	remaining: 143ms
# 1300:	learn: 43129.6676243	total: 625ms	remaining: 95.6ms
# 1400:	learn: 42889.0582928	total: 677ms	remaining: 47.8ms
# 1499:	learn: 42667.4875546	total: 727ms	remaining: 0us
# 0:	learn: 60860.6403080	total: 585us	remaining: 877ms
# 100:	learn: 41703.5108081	total: 51.3ms	remaining: 710ms
# 200:	learn: 39830.6260317	total: 101ms	remaining: 654ms
# 300:	learn: 39061.4808293	total: 151ms	remaining: 600ms
# 400:	learn: 38638.9064526	total: 202ms	remaining: 553ms
# 500:	learn: 38388.4674151	total: 254ms	remaining: 506ms
# 600:	learn: 38214.4822194	total: 306ms	remaining: 458ms
# 700:	learn: 38106.5115334	total: 357ms	remaining: 407ms
# 800:	learn: 38031.4147518	total: 406ms	remaining: 355ms
# 900:	learn: 37983.4475734	total: 456ms	remaining: 303ms
# 1000:	learn: 37943.7138086	total: 506ms	remaining: 252ms
# 1100:	learn: 37915.9741675	total: 555ms	remaining: 201ms
# 1200:	learn: 37892.0085805	total: 607ms	remaining: 151ms
# 1300:	learn: 37876.2291929	total: 656ms	remaining: 100ms
# 1400:	learn: 37862.1159243	total: 704ms	remaining: 49.8ms
# 1499:	learn: 37852.5656508	total: 754ms	remaining: 0us
# 0:	learn: 60856.8258042	total: 2.21ms	remaining: 3.31s
# 100:	learn: 42674.0184305	total: 49.3ms	remaining: 683ms
# 200:	learn: 40685.2972010	total: 98.8ms	remaining: 639ms
# 300:	learn: 39837.3304986	total: 148ms	remaining: 588ms
# 400:	learn: 39410.9382545	total: 198ms	remaining: 544ms
# 500:	learn: 39156.3274479	total: 249ms	remaining: 496ms
# 600:	learn: 39010.6995349	total: 299ms	remaining: 448ms
# 700:	learn: 38908.8669330	total: 349ms	remaining: 398ms
# 800:	learn: 38848.0882015	total: 401ms	remaining: 350ms
# 900:	learn: 38797.1689391	total: 453ms	remaining: 301ms
# 1000:	learn: 38759.7709282	total: 504ms	remaining: 251ms
# 1100:	learn: 38728.0649645	total: 556ms	remaining: 202ms
# 1200:	learn: 38706.4652188	total: 606ms	remaining: 151ms
# 1300:	learn: 38688.2553986	total: 659ms	remaining: 101ms
# 1400:	learn: 38674.0473219	total: 709ms	remaining: 50.1ms
# 1499:	learn: 38662.6896349	total: 758ms	remaining: 0us
# 0:	learn: 61211.6218274	total: 420us	remaining: 631ms
# 100:	learn: 44044.2997614	total: 48.9ms	remaining: 677ms
# 200:	learn: 41841.9251419	total: 99.4ms	remaining: 642ms
# 300:	learn: 41005.5174595	total: 152ms	remaining: 606ms
# 400:	learn: 40564.9855984	total: 206ms	remaining: 564ms
# 500:	learn: 40333.7573423	total: 260ms	remaining: 518ms
# 600:	learn: 40183.7577049	total: 313ms	remaining: 468ms
# 700:	learn: 40080.3325238	total: 366ms	remaining: 418ms
# 800:	learn: 40011.5266767	total: 416ms	remaining: 363ms
# 900:	learn: 39960.6698535	total: 467ms	remaining: 311ms
# 1000:	learn: 39920.3117541	total: 526ms	remaining: 262ms
# 1100:	learn: 39889.0137214	total: 581ms	remaining: 211ms
# 1200:	learn: 39868.0133667	total: 636ms	remaining: 158ms
# 1300:	learn: 39853.1531429	total: 690ms	remaining: 106ms
# 1400:	learn: 39839.8062352	total: 744ms	remaining: 52.6ms
# 1499:	learn: 39830.1241607	total: 796ms	remaining: 0us
# 0:	learn: 58760.9593574	total: 1.26ms	remaining: 1.9s
# 100:	learn: 39842.6796612	total: 54.8ms	remaining: 759ms
# 200:	learn: 38685.5856301	total: 108ms	remaining: 695ms
# 300:	learn: 38247.3674481	total: 160ms	remaining: 637ms
# 400:	learn: 38054.8167762	total: 213ms	remaining: 585ms
# 500:	learn: 37957.9510278	total: 269ms	remaining: 537ms
# 600:	learn: 37896.8087266	total: 321ms	remaining: 480ms
# 700:	learn: 37865.8959941	total: 373ms	remaining: 425ms
# 800:	learn: 37846.4957854	total: 424ms	remaining: 370ms
# 900:	learn: 37835.5327105	total: 473ms	remaining: 314ms
# 1000:	learn: 37828.7619889	total: 524ms	remaining: 261ms
# 1100:	learn: 37823.2835068	total: 577ms	remaining: 209ms
# 1200:	learn: 37819.7577800	total: 629ms	remaining: 157ms
# 1300:	learn: 37817.3982278	total: 680ms	remaining: 104ms
# 1400:	learn: 37815.6781115	total: 729ms	remaining: 51.5ms
# 1499:	learn: 37814.4467587	total: 777ms	remaining: 0us
# 0:	learn: 58819.5307400	total: 465us	remaining: 698ms
# 100:	learn: 40569.1702244	total: 51.9ms	remaining: 719ms
# 200:	learn: 39331.4368333	total: 106ms	remaining: 686ms
# 300:	learn: 38961.3580353	total: 156ms	remaining: 620ms
# 400:	learn: 38811.8424306	total: 208ms	remaining: 570ms
# 500:	learn: 38730.4561790	total: 258ms	remaining: 515ms
# 600:	learn: 38685.6673446	total: 310ms	remaining: 464ms
# 700:	learn: 38660.2361816	total: 359ms	remaining: 409ms
# 800:	learn: 38646.6488834	total: 411ms	remaining: 358ms
# 900:	learn: 38636.5476166	total: 461ms	remaining: 306ms
# 1000:	learn: 38629.0327739	total: 510ms	remaining: 254ms
# 1100:	learn: 38625.0783129	total: 562ms	remaining: 204ms
# 1200:	learn: 38621.6686529	total: 613ms	remaining: 153ms
# 1300:	learn: 38619.6090637	total: 664ms	remaining: 102ms
# 1400:	learn: 38618.2861109	total: 713ms	remaining: 50.4ms
# 1499:	learn: 38617.3955167	total: 762ms	remaining: 0us
# 0:	learn: 59400.5007808	total: 527us	remaining: 790ms
# 100:	learn: 41846.9043244	total: 48.7ms	remaining: 674ms
# 200:	learn: 40587.9742082	total: 101ms	remaining: 655ms
# 300:	learn: 40173.6086206	total: 151ms	remaining: 602ms
# 400:	learn: 40008.0206695	total: 201ms	remaining: 550ms
# 500:	learn: 39917.7002463	total: 251ms	remaining: 500ms
# 600:	learn: 39871.3249153	total: 302ms	remaining: 452ms
# 700:	learn: 39840.4144452	total: 353ms	remaining: 402ms
# 800:	learn: 39823.9329423	total: 403ms	remaining: 351ms
# 900:	learn: 39812.6806227	total: 454ms	remaining: 302ms
# 1000:	learn: 39805.5227558	total: 503ms	remaining: 251ms
# 1100:	learn: 39800.9348868	total: 554ms	remaining: 201ms
# 1200:	learn: 39797.4796755	total: 604ms	remaining: 150ms
# 1300:	learn: 39795.2940231	total: 653ms	remaining: 99.8ms
# 1400:	learn: 39793.9754437	total: 704ms	remaining: 49.7ms
# 1499:	learn: 39792.8620381	total: 751ms	remaining: 0us
# 0:	learn: 62847.6934796	total: 1.19ms	remaining: 1.78s
# 100:	learn: 50658.1919699	total: 45.3ms	remaining: 627ms
# 200:	learn: 47697.6522299	total: 89.9ms	remaining: 581ms
# 300:	learn: 46678.5905837	total: 134ms	remaining: 535ms
# 400:	learn: 46167.4898389	total: 177ms	remaining: 485ms
# 500:	learn: 45809.0360607	total: 219ms	remaining: 436ms
# 600:	learn: 45515.6706535	total: 262ms	remaining: 392ms
# 700:	learn: 45271.0352320	total: 304ms	remaining: 347ms
# 800:	learn: 45029.4937986	total: 348ms	remaining: 303ms
# 900:	learn: 44778.9457913	total: 389ms	remaining: 258ms
# 1000:	learn: 44531.3983283	total: 433ms	remaining: 216ms
# 1100:	learn: 44314.5248446	total: 479ms	remaining: 174ms
# 1200:	learn: 44089.4671163	total: 527ms	remaining: 131ms
# 1300:	learn: 43888.2512005	total: 574ms	remaining: 87.8ms
# 1400:	learn: 43698.6220620	total: 624ms	remaining: 44.1ms
# 1499:	learn: 43523.2421910	total: 671ms	remaining: 0us
# Время подбора гиперпараметров: 32.31 секунд
# Лучшие параметры: {'depth': 6, 'iterations': 1500, 'learning_rate': 0.01}
# Среднеквадратичная ошибка (RMSE) с лучшими параметрами: 47958.6274
# Коэффициент детерминации (R^2) с лучшими параметрами: 0.4174

# %% [markdown]
# ## **Задание 13 (1 балл)**
#
# - Используйте xgboost.
# - Обучите модель — на полном наборе данных с категориальными признаками. Стратегию кодирования оставьте ту, что показала себя лучшей в пункте 9.
# - Подберите оптимальные гиперпараметры.
# - Оцените качество итоговой модели, скорость обучения и скорость предсказания.

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

# %%
# Создаём модель
model_xgb = XGBRegressor(random_state=42)

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

grid_search = GridSearchCV(estimator=model_xgb, 
                           param_grid=param_grid, 
                           cv=3, 
                           scoring='neg_mean_squared_error')

start_time = time.time()
grid_search.fit(X_train_encoded_mte, y_train)
end_time = time.time()

# время обучения
print(f"Время обучения: {end_time - start_time:.2f} секунд")
# Out:
# Время обучения: 57.15 секунд

# %%
# Лучшие гиперпараметры
best_params = grid_search.best_params_
best_model_xgb = grid_search.best_estimator_

# %%
start_pred_time = time.time()
y_pred = best_model_xgb.predict(X_test_encoded_mte)
end_pred_time = time.time()

# метрики
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R^2: {r2}")
print(f"Время предсказания: {end_pred_time - start_pred_time:.2f} секунд")
# Out:
# RMSE: 48581.25136305157
# MAE: 36987.45703125
# R^2: 0.40216219425201416
# Время предсказания: 0.00 секунд

# %% [markdown]
# ## **Задание 14 (1 балл)**
#
# - Используйте lgbm.
# - Обучите модель — на полном наборе данных с категориальными признаками. Стратегию кодирования оставьте ту, что показала себя лучшей в пункте 9.
# - Подберите оптимальные гиперпараметры.
# - Оцените качество итоговой модели, скорость обучения и скорость предсказания.

# %%
from lightgbm import LGBMRegressor

# %%
model = LGBMRegressor(random_state=42)

# Подбор гиперпараметров с помощью GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'num_leaves': [31, 50, 100],
    'subsample': [0.8, 1.0]
}

grid_search = GridSearchCV(estimator=model, 
                           param_grid=param_grid, 
                           cv=3, 
                           scoring='neg_mean_squared_error')

start_time = time.time()
grid_search.fit(X_train_encoded_mte, y_train)
end_time = time.time()

print(f"Время обучения: {end_time - start_time:.2f} секунд")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000503 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 149
# [LightGBM] [Info] Number of data points in the train set: 2002, number of used features: 8
# [LightGBM] [Info] Start training from score 137264.451548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000438 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 151
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 8
# [LightGBM] [Info] Start training from score 137449.426860
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 141
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 7
# [LightGBM] [Info] Start training from score 139453.694458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000466 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 149
# [LightGBM] [Info] Number of data points in the train set: 2002, number of used features: 8
# [LightGBM] [Info] Start training from score 137264.451548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 151
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 8
# [LightGBM] [Info] Start training from score 137449.426860
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 141
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 7
# [LightGBM] [Info] Start training from score 139453.694458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 149
# [LightGBM] [Info] Number of data points in the train set: 2002, number of used features: 8
# [LightGBM] [Info] Start training from score 137264.451548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000483 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 151
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 8
# [LightGBM] [Info] Start training from score 137449.426860
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 141
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 7
# [LightGBM] [Info] Start training from score 139453.694458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000447 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 149
# [LightGBM] [Info] Number of data points in the train set: 2002, number of used features: 8
# [LightGBM] [Info] Start training from score 137264.451548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000453 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 151
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 8
# [LightGBM] [Info] Start training from score 137449.426860
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000400 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 141
# [LightGBM] [Info] Number of data points in the train set: 2003, number of used features: 7
# [LightGBM] [Info] Start training from score 139453.694458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000469 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 173
# [LightGBM] [Info] Number of data points in the train set: 3004, number of used features: 8
# [LightGBM] [Info] Start training from score 138055.989348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Время обучения: 163.04 секунд

# %%
# Лучшие гиперпараметры
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
print("Лучшие гиперпараметры:", best_params)
# Out:
# Лучшие гиперпараметры: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 50, 'num_leaves': 50, 'subsample': 0.8}

# %%
start_pred_time = time.time()
y_pred = best_model.predict(X_test_encoded_mte)
end_pred_time = time.time()

# Метрики качества
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R²: {r2}")

print(f"Время предсказания: {end_pred_time - start_pred_time:.2f} секунд")
# Out:
# RMSE: 48646.18673720077
# MAE: 37016.840303049445
# R²: 0.4005629522559305
# Время предсказания: 0.00 секунд

# %% [markdown]
# ## **Задание 15 (0.4 балла)**

# %% [markdown]
# Сделайте выводы про модели и решение задачи.
#
# - Какая из моделей показала лучший результат по качеству?
# - Какая из моделей показала лучший результат по качеству, скорости обучения и скорости предсказания в совокупности?
# - Насколько бустинги превзошли линейную модель? Целесообразно ли их использование?

# %% [markdown]
# По всем критериям лидирует catboost (минимальное время обучения при наивысшем качестве)

# %% [markdown]
# # **Часть 2: кластеризация типов движений**
# **Количество баллов:** 3

# %% [markdown]
# В этой части будем работать с набором данных Samsung Human Activity Recognition. Набор данных заранее предобработан и снова доступен вам по [ссылке](https://drive.google.com/file/d/16ISu7lMumt5rbticbOggHMRjwTGBETtO/view?usp=sharing).
#
# ### **Постановка задачи**
# Данные поступают с акселерометров и гироскопов мобильных телефонов Samsung Galaxy S2. Вид активности человека с телефоном в кармане известен:
# - 1 - ходьба,
# - 2 - подъем вверх по лестнице,
# - 3 - спуск по лестнице,
# - 4 - сидение,
# - 5 - стояние,
# - 6 - лежание
#
#
# Представим, что вид активности нам неизвестнен, и попробуем кластеризовать людей чисто на основе имеющихся признаков.

# %%
# import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt


# plt.style.use(['seaborn-darkgrid'])
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.family'] = 'DejaVu Sans'

# %matplotlib inline
# %config InlineBackend.figure_format="retina"

RANDOM_STATE = 42

# %%
test_labels = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_test_labels.txt',                 delim_whitespace=True, header=None)

test = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_test.txt', delim_whitespace=True, header=None)

train_labels = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_train_labels.txt', delim_whitespace=True, header=None)

train = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_train.txt', delim_whitespace=True, header=None)
# Out:
# /var/folders/b5/7wyqv1652bj52cb4jlgfcldc0000gr/T/ipykernel_18957/1493188491.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_labels = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_test_labels.txt',                 delim_whitespace=True, header=None)
# /var/folders/b5/7wyqv1652bj52cb4jlgfcldc0000gr/T/ipykernel_18957/1493188491.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_test.txt', delim_whitespace=True, header=None)
# /var/folders/b5/7wyqv1652bj52cb4jlgfcldc0000gr/T/ipykernel_18957/1493188491.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train_labels = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_train_labels.txt', delim_whitespace=True, header=None)
# /var/folders/b5/7wyqv1652bj52cb4jlgfcldc0000gr/T/ipykernel_18957/1493188491.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   train = pd.read_csv('/Users/vitaly/Documents/1_Образование/Государственное/ВШЭ/Предметы/3_ML/HW_5_datasets/samsung_train.txt', delim_whitespace=True, header=None)

# %%
test_labels.head()
# Out:
#    0
# 0  5
# 1  5
# 2  5
# 3  5
# 4  5

# %%
test
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1     0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2     0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3     0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4     0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
# ...        ...       ...       ...       ...       ...       ...       ...
# 2942  0.310155 -0.053391 -0.099109 -0.287866 -0.140589 -0.215088 -0.356083
# 2943  0.363385 -0.039214 -0.105915 -0.305388  0.028148 -0.196373 -0.373540
# 2944  0.349966  0.030077 -0.115788 -0.329638 -0.042143 -0.250181 -0.388017
# 2945  0.237594  0.018467 -0.096499 -0.323114 -0.229775 -0.207574 -0.392380
# 2946  0.153627 -0.018437 -0.137018 -0.330046 -0.195253 -0.164339 -0.430974
#
#            7         8         9    ...       551       552       553  \
# 0    -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974
# 1    -0.968401 -0.945823 -0.894088  ... -0.401189 -0.121845 -0.594944
# 2    -0.970735 -0.963483 -0.939260  ...  0.062891 -0.190422 -0.640736
# 3    -0.974471 -0.968897 -0.938610  ...  0.116695 -0.344418 -0.736124
# 4    -0.965953 -0.977346 -0.938610  ... -0.121711 -0.534685 -0.846595
# ...        ...       ...       ...  ...       ...       ...       ...
# 2942 -0.148775 -0.232057  0.185361  ...  0.074472 -0.376278 -0.750809
# 2943 -0.030036 -0.270237  0.185361  ...  0.101859 -0.320418 -0.700274
# 2944 -0.133257 -0.347029  0.007471  ... -0.066249 -0.118854 -0.467179
# 2945 -0.279610 -0.289477  0.007471  ... -0.046467 -0.205445 -0.617737
# 2946 -0.218295 -0.229933 -0.111527  ... -0.010386 -0.072237 -0.436940
#
#            554       555       556       557       558       559       560
# 0     0.006462  0.162920 -0.825886  0.271151 -0.720009  0.276801 -0.057978
# 1    -0.083495  0.017500 -0.434375  0.920593 -0.698091  0.281343 -0.083898
# 2    -0.034956  0.202302  0.064103  0.145068 -0.702771  0.280083 -0.079346
# 3    -0.017067  0.154438  0.340134  0.296407 -0.698954  0.284114 -0.077108
# 4    -0.002223 -0.040046  0.736715 -0.118545 -0.692245  0.290722 -0.073857
# ...        ...       ...       ...       ...       ...       ...       ...
# 2942 -0.337422  0.346295  0.884904 -0.698885 -0.651732  0.274627  0.184784
# 2943 -0.736701 -0.372889 -0.657421  0.322549 -0.655181  0.273578  0.182412
# 2944 -0.181560  0.088574  0.696663  0.363139 -0.655357  0.274479  0.181184
# 2945  0.444558 -0.819188  0.929294 -0.008398 -0.659719  0.264782  0.187563
# 2946  0.598808 -0.287951  0.876030 -0.024965 -0.660080  0.263936  0.188103
#
# [2947 rows x 561 columns]

# %% [markdown]
# ### **Задание 16 (0.1 балл)**
# Прочитайте данные из файлов и объедните тестовую и обучающие выборки.
#
# В файлах ```..._labels``` лежат настоящие классы. Их также объедините, но в отдельную переменную (например ```y```). Данный вектор для кластеризации нам не нужен, но мы будем смотреть по нему метрики.

# %%
# Ваш код здесь
X = pd.concat([train, test], axis=0, ignore_index=True)
y = pd.concat([train_labels, test_labels], axis=0, ignore_index=True)

# %%
X
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1      0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2      0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3      0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4      0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294  0.310155 -0.053391 -0.099109 -0.287866 -0.140589 -0.215088 -0.356083
# 10295  0.363385 -0.039214 -0.105915 -0.305388  0.028148 -0.196373 -0.373540
# 10296  0.349966  0.030077 -0.115788 -0.329638 -0.042143 -0.250181 -0.388017
# 10297  0.237594  0.018467 -0.096499 -0.323114 -0.229775 -0.207574 -0.392380
# 10298  0.153627 -0.018437 -0.137018 -0.330046 -0.195253 -0.164339 -0.430974
#
#             7         8         9    ...       551       552       553  \
# 0     -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304
# 1     -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499
# 2     -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104
# 3     -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845
# 4     -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205
# ...         ...       ...       ...  ...       ...       ...       ...
# 10294 -0.148775 -0.232057  0.185361  ...  0.074472 -0.376278 -0.750809
# 10295 -0.030036 -0.270237  0.185361  ...  0.101859 -0.320418 -0.700274
# 10296 -0.133257 -0.347029  0.007471  ... -0.066249 -0.118854 -0.467179
# 10297 -0.279610 -0.289477  0.007471  ... -0.046467 -0.205445 -0.617737
# 10298 -0.218295 -0.229933 -0.111527  ... -0.010386 -0.072237 -0.436940
#
#             554       555       556       557       558       559       560
# 0     -0.112754  0.030400 -0.464761 -0.018446 -0.841247  0.179941 -0.058627
# 1      0.053477 -0.007435 -0.732626  0.703511 -0.844788  0.180289 -0.054317
# 2     -0.118559  0.177899  0.100699  0.808529 -0.848933  0.180637 -0.049118
# 3     -0.036788 -0.012892  0.640011 -0.485366 -0.848649  0.181935 -0.047663
# 4      0.123320  0.122542  0.693578 -0.615971 -0.847865  0.185151 -0.043892
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294 -0.337422  0.346295  0.884904 -0.698885 -0.651732  0.274627  0.184784
# 10295 -0.736701 -0.372889 -0.657421  0.322549 -0.655181  0.273578  0.182412
# 10296 -0.181560  0.088574  0.696663  0.363139 -0.655357  0.274479  0.181184
# 10297  0.444558 -0.819188  0.929294 -0.008398 -0.659719  0.264782  0.187563
# 10298  0.598808 -0.287951  0.876030 -0.024965 -0.660080  0.263936  0.188103
#
# [10299 rows x 561 columns]

# %%
y
# Out:
#        0
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
# ...   ..
# 10294  2
# 10295  2
# 10296  2
# 10297  2
# 10298  2
#
# [10299 rows x 1 columns]

# %%
# убедимся, что y содержит нужные нам классы
np.unique(y)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### **Задание 17 (0.2 балла)**
#
# Так как мы будем пользоваться метрическими алгоритмами, отмасштабируйте выборку с помощью ```StandardScaler```.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.210534 -0.068703 -0.452195 -0.883335 -0.945431 -0.744387 -0.874687
# 1      0.060208  0.035902 -0.275222 -0.890098 -0.929817 -0.860322 -0.883627
# 2      0.078460 -0.046427 -0.085548 -0.883565 -0.913598 -0.906457 -0.878093
# 3      0.071375 -0.227794 -0.270741 -0.885188 -0.946015 -0.935521 -0.879495
# 4      0.033738  0.031617 -0.121380 -0.889855 -0.940846 -0.935041 -0.882451
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294  0.529503 -0.960174  0.185107  0.729285  0.738886  0.985976  0.671427
# 10295  1.316644 -0.578309  0.056759  0.689343  1.076214  1.032342  0.629191
# 10296  1.118216  1.288059 -0.129415  0.634062  0.935694  0.899035  0.594164
# 10297 -0.543493  0.975327  0.234320  0.648934  0.560590  1.004592  0.583607
# 10298 -1.785153 -0.018666 -0.529760  0.633133  0.629605  1.111706  0.490231
#
#             7         8         9    ...       551       552       553  \
# 0     -0.944877 -0.773250 -0.868773  ... -0.819093 -0.000264 -0.299902
# 1     -0.927796 -0.858859 -0.884263  ...  0.127803 -0.925905 -0.789555
# 2     -0.904569 -0.908437 -0.876139  ...  1.172610 -0.287824 -0.461181
# 3     -0.943980 -0.938095 -0.876139  ...  1.132149  0.566244  0.436736
# 4     -0.937622 -0.940948 -0.883152  ... -0.158720 -0.165153 -0.263958
# ...         ...       ...       ...  ...       ...       ...       ...
# 10294  0.778479  0.959693  1.210539  ... -0.212834 -0.242630 -0.431080
# 10295  1.023717  0.864009  1.210539  ... -0.101244 -0.068167 -0.267420
# 10296  0.810529  0.671554  0.880306  ... -0.786194  0.561361  0.487469
# 10297  0.508257  0.815788  0.880306  ... -0.705592  0.290917 -0.000118
# 10298  0.634896  0.965017  0.659399  ... -0.558583  0.706954  0.585400
#
#             554       555       556       557       558       559       560
# 0     -0.357898  0.062039 -0.782988 -0.019034 -0.674432  0.382008 -0.016151
# 1      0.135993 -0.022538 -1.217721  1.470315 -0.681360  0.383148 -0.000121
# 2     -0.375145  0.391762  0.134732  1.686961 -0.689471  0.384289  0.019214
# 3     -0.132194 -0.034739  1.010013 -0.982261 -0.688915  0.388536  0.024624
# 4      0.343504  0.268015  1.096950 -1.251689 -0.687381  0.399066  0.038649
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294 -1.025409  0.768198  1.407463 -1.422736 -0.303659  0.691994  0.889111
# 10295 -2.211711 -0.839484 -1.095665  0.684415 -0.310406  0.688561  0.880288
# 10296 -0.562328  0.192082  1.101957  0.768150 -0.310750  0.691509  0.875719
# 10297  1.297936 -1.837152  1.479507  0.001693 -0.319284  0.659762  0.899444
# 10298  1.756231 -0.649611  1.393061 -0.032483 -0.319991  0.656994  0.901454
#
# [10299 rows x 561 columns]

# %% [markdown]
# ### **Задание 18 (0.5 балла)**
#
# Данных много и размерность большая. Чтобы ускорить рещение задачи с точки зрения построения модели, мы используем методы **понижения размерности**.
#
# - Понизьте размерность с помощью `PCA`, оставляя столько компонент, сколько нужно для того, чтобы объяснить как минимум 90% дисперсии отмасштабированных данных. Вам пригодится [документация](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)
#
# **Примечание:**
# Для этого сумма значений массива pca.explained_variance_ratio_ должна быть не меньше 0.9.  ```random_state``` используйте из объявленной в самом начале переменной ```RANDOM_STATE``` (42).

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.90, random_state=42)

pca.fit(X_scaled)

reduced_data = pca.transform(X_scaled)

X_pca = pd.DataFrame(reduced_data, columns=[x for x in range(1,66)])

# %%
X_pca
# Out:
#               1         2         3         4         5         6         7   \
# 0     -16.380980  1.995083  3.415690  0.649858 -7.825062 -2.771964 -2.298285
# 1     -15.582173  1.182594 -0.321207 -2.748083 -4.729536 -1.588823  0.334051
# 2     -15.423989  2.243166 -1.237784 -4.002881 -4.402735 -1.035089  0.129769
# 3     -15.647807  3.762882 -1.275283 -2.806663 -3.239111 -0.743524 -0.326070
# 4     -15.842320  4.438897 -1.808232 -3.160507 -3.331172 -0.911551  0.861931
# ...          ...       ...       ...       ...       ...       ...       ...
# 10294  10.166057 -6.504223 -1.055480 -3.284351  3.092322  1.826406 -1.115329
# 10295  12.131154 -4.882447 -0.652943 -2.843124  1.855674 -0.237809 -0.942492
# 10296  11.846853 -3.433565  2.188019 -2.376461  0.097417  0.339711 -1.477391
# 10297   8.206686 -4.386489  1.318720 -3.571492  0.861809  0.819570 -2.610082
# 10298   9.311173 -3.986161  1.933017 -5.086123  3.037353  1.096976 -3.636130
#
#              8         9         10  ...        56        57        58  \
# 0     -5.227723  1.335530 -3.760130  ... -1.506035 -0.781218  2.298251
# 1     -1.621178  0.006349  0.072030  ...  0.825520 -1.238370  0.574630
# 2     -1.279185 -0.190748 -0.780891  ... -0.049957 -0.094588  0.482925
# 3     -1.742983 -0.912218 -1.594744  ...  0.308788  1.567928  0.372501
# 4     -0.090126 -0.521629  1.015852  ... -0.006348 -0.073779 -0.743167
# ...         ...       ...       ...  ...       ...       ...       ...
# 10294  3.700841  0.458237  0.227647  ...  0.523421 -0.789725  1.049283
# 10295  1.649241  1.255467  1.501563  ...  0.724734 -1.360103  0.368710
# 10296  0.108231  1.133958 -0.485808  ...  0.596142 -1.375539 -0.032523
# 10297  1.137181  1.477443 -0.533054  ...  0.262820  1.168796 -1.263935
# 10298  0.508921  0.524584 -3.004100  ... -0.581962  0.767528  0.343539
#
#              59        60        61        62        63        64        65
# 0     -0.762634  0.793773  0.966931 -0.538175 -0.342570  0.243974 -1.946787
# 1     -0.279049 -0.455333  0.326308 -0.308416 -0.137421  0.160813 -0.614320
# 2     -0.982975  0.048405 -0.040423  0.061110  1.470980  1.243111  0.246722
# 3     -0.706237 -1.081383  0.595845  0.647765  2.245285 -1.007824  4.239617
# 4     -0.648799 -0.406167 -0.199058  0.392289  0.494461  0.798755 -0.165762
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294 -0.176700 -0.080074 -1.346695 -0.358640  0.128719  0.479910 -0.985991
# 10295 -0.329186 -0.082377 -1.727428 -0.847686 -0.183105 -0.625335 -1.039937
# 10296  1.950166  2.138688  1.900237 -3.680339  0.944670  0.344980 -2.094656
# 10297  1.412382 -0.188709 -1.092362 -0.877534 -0.117234  1.327861  0.087424
# 10298  0.804794  0.231459  1.042440 -1.644063 -0.129882  1.863964 -0.182535
#
# [10299 rows x 65 columns]

# %%
print(pca.n_components_)
# Out:
# 65

# %% [markdown]
# ### **Задание 19 (0.2 балла)**
#
# Визуализируйте данные в проекции на первые две главные компоненты. Используйте ```cmap="virdis"``` или любой другой, с которым будет красиво!
#
# Можете раскрасить кластеры.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_pca.iloc[:, 0], X_pca.iloc[:, 1], cmap='viridis', s=50, alpha=0.8)
plt.colorbar(label='Интенсивность')
plt.title('Проекция данных на первые две главные компоненты (PCA)')
plt.xlabel('Первая главная компонента')
plt.ylabel('Вторая главная компонента')
plt.grid(True)
plt.show()
# Out:
# /var/folders/b5/7wyqv1652bj52cb4jlgfcldc0000gr/T/ipykernel_18957/457502982.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_pca.iloc[:, 0], X_pca.iloc[:, 1], cmap='viridis', s=50, alpha=0.8)

# %% [markdown]
# ### **Задание 19. (0.5 балла)**
#
# Разберёмся с `KMeans`, [doc](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
#
# - Сделайте кластеризацию данных методом `KMeans`, обучив модель на данных со сниженной за счет `PCA` размерностью. Нужно искать 6 кластеров (изначально у нас 6 классов). Засеките время обучения и время инференса.
#
# **Параметры обучения:**
#
# ```n_clusters = 6``` (число уникальных меток целевого класса = 6)
#
# ```n_init = 100```
#
# ```random_state = RANDOM_STATE``` (для воспроизводимости результата, не забывайте указывать его и дальше!)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=6, n_init=100, random_state=42)

# время обучения
training_start_time = time.time()
kmeans.fit(X_pca)
training_time = time.time() - training_start_time

# время инференса
inference_start_time = time.time()
labels = kmeans.predict(X_pca)
inference_time = time.time() - inference_start_time

print(f"Время обучения: {training_time} секунд")
print(f"Время инференса: {inference_time} секунд")

# метки кластеров
print(f"Метки кластеров: {labels}")
# Out:
# Время обучения: 15.105422973632812 секунд
# Время инференса: 0.012655973434448242 секунд
# Метки кластеров: [2 2 2 ... 3 3 3]

# %% [markdown]
# ### **Задание 20 (0.2 балла)**
#
# - Визуализируйте данные в проекции на первые две главные компоненты.
# - Раскрасьте точки в соответствии с полученными метками кластеров.

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca.iloc[:, 0], X_pca.iloc[:, 1], c=labels, cmap='viridis', s=50, alpha=0.8)
plt.colorbar(scatter, label='Кластеры')
plt.title('Проекция данных на первые две главные компоненты (PCA) с кластерами')
plt.xlabel('Первая главная компонента')
plt.ylabel('Вторая главная компонента')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Задание 21 (0.3 балла)**
#
# - Выберите какие-то метрики (минимум две) из известных вам. Объясните свой выбор
# - Выведите на экран значения метрик качества, сделайте вывод о них и используйте их далее.

# %% [markdown]
#     Будем оценивать по V-measure (как критерий для знания реальных меток) и Silhouette Score (как показатель разделимости кластеров)

# %%
from sklearn.metrics import silhouette_score, v_measure_score

# %%
print(f"Silhouette Score: {silhouette_score(X_pca, labels)}")
print(f"V-Measure: {v_measure_score(y[0].values, labels)}")
# Out:
# Silhouette Score: 0.14149759467581455
# V-Measure: 0.5600410921019029

# %% [markdown]
# Кластеры плохо разделимы (по силуэту), а кластеры лишь частично соответствуют истинным меткам (по V-score)

# %% [markdown]
# ### **Задание 22 (0.7 баллов)**
#
# Теперь попробуем сделать кластеризацию с помощью `AgglomerativeClustering`, [doc](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html)
#
# - Засеките время обучения и время инференса. После кластеризации также:
#   - Вновь визуализируйте данные с раскраской по полученным меткам
#   - Выведите метрики. Засеките время обучения и время инференса. Сравните с ```KMeans```.
#
# Ответьте на следующие вопросы:
# * Стало ли лучше?
# * Почему?

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
agg_clustering = AgglomerativeClustering(n_clusters=6)

# время обучения
start_time = time.time()
agg_clustering.fit(X_pca)  # Обучение модели
training_time = time.time() - start_time
print(f"Время обучения: {training_time:.4f} секунд")

# время инференса
start_time = time.time()
clusters = agg_clustering.fit_predict(X_pca)  # Предсказание меток
inference_time = time.time() - start_time
print(f"Время инференса: {inference_time:.4f} секунд")

plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca.iloc[:, 0], X_pca.iloc[:, 1], c=clusters, cmap='viridis', s=50, alpha=0.8)
plt.colorbar(scatter, label='Кластеры')
plt.title('Проекция данных на первые две главные компоненты (PCA) с кластерами (AgglomerativeClustering)')
plt.xlabel('Первая главная компонента')
plt.ylabel('Вторая главная компонента')
plt.grid(True)
plt.show()
# Out:
# Время обучения: 1.4498 секунд
# Время инференса: 1.4169 секунд

# %%
print(f"Silhouette Score: {silhouette_score(X_pca, clusters)}")
print(f"V-Measure: {v_measure_score(y[0].values, clusters)}")
# Out:
# Silhouette Score: 0.1365817987962443
# V-Measure: 0.6217855076000528

# %% [markdown]
# **Так как Kmeans пытается сделать кластеры круглыми областями, при нем метрика разделимости была лучше.** \
# **При этом качество самой кластеризации по известным значениям стало лучше (с 56% до 62%)**

# %% [markdown]
# ### **Задание 23 (0.3 балла)**
# Для самой успешной из полученных кластеризаций попробуйте дать интерпретацию кластеров. Опишите характеристики объектов, попавших в каждый кластер. Для этого можете ответить на следующие вопросы:
#
# * Похожи ли объекты внутри каждого кластера на определенный тип активности человека?
# * В каких кластерах смешано несколько типов активности? С чем, на ваш взгляд, это может быть связано?
# * Качественная ли получилась кластеризация? На основании чего вы можете сделать такой вывод?

# %% [markdown]
# **Без знания признаков, тяжело сказать, насколько типы активности похож на кластер, но заметен самый отдаленый кластер (в правом верхнем углу графика) - скорее всего это лежание, так как его проще всего отличить.** \
# **А среди замешанных, думаю, находятся ходьба, подъем и спуск по лестнице - это довольно похожие действия, поэтому они смешаны**
# **По качеству, мы конечно не угадываем, но качество довольно слабое. Думаю, в самой разметке с телефона нет сильных признаков, по которым можно было бы с хорошей уверенностью отличать подъем и спуск по лестнице например.**

# %% [markdown]
# ## **Бонус-задание (1 балл)**
# ![RedPanda](http://imgur.com/6Aa52Lm.png)
#
# Алгоритмы кластеризации могут применяться в самых разных задачах. Например, в анализе изображений есть задача разделения изображения на семантические компоненты, которую можно решать в том числе с помощью алгоритмов кластеризации. В бонусе предлагаем вам попрактиковаться именно в этом на чудесной утке и совах (```duck.jpg``` и ```owls.jpg```)

# %% [markdown]
# ### **(0.1 балл)**
#
# - Откройте изображения, после чего визуализируйте их с помощью ```plt.imshow()```

# %%
from PIL import Image
# or
#import cv2

# %% [markdown]
# ### **(0.4 балла)**
#
# Для каждого изображения, используя кластеризацию ```KMeans```, выделите компоненты, охарактеризовав каждый пиксель следующим образом: $$\psi_i = [\lambda x_i, \lambda y_i, r_i, g_i, b_i]$$
#  где
# - $x_i$ и $y_i$ — координаты пикселя,
# - $r_i, g_i, b_i$ — его цвет,
# - $\lambda$ — параметр, выражающий важность пространственной связности перед цветовой похожестью.
#
# Примените полученную функцию, взяв следующие $\lambda$: 0.3 и 1.5 для ```duck.jpg``` и ```owls.jpg``` (или другие, но тогда с вас красивые результаты :) )
#
# **Примечание:**
# Число кластеров подберите разумным образом на свой вкус (в качестве нулевого приближения можно взять 3)

# %%
def find_components(image, lmbd, n_clusters):
    #your code here
# Out:
#   Cell In[335], line 2
#     #your code here
#                    ^
# SyntaxError: incomplete input

# %% [markdown]
# ### **(0.4 балла)**
#
# Попробуйте выделить сегменты при помощи [спектральной кластеризации](http://scikit-learn.org/stable/modules/clustering.html#spectral-clustering). Обратите внимание на [пример в sklearn](http://scikit-learn.org/0.16/auto_examples/cluster/plot_lena_segmentation.html).
#
#
# **Примечание:**
#
# Для ускорения работы алгоритма рекомендуется привести изображение к серому цвету. При необходимости можно сжать изображения в 2 раза.
#
# **Подсказка:**```skimage``` с его ```color``` и ```transform``` в этом помогут :)
#
# Или же воспользуйтесь аналогичными средствами ```PIL``` или ```cv2```

# %%
def spectral_segmentation(image, n_clusters, beta, eps):
    #your code here

# %% [markdown]
# ### **(0.1 балл)**
# Визуализируйте результаты сегментации (аналогично рисунку в начале задания 2) для обоих методов.

# %% [markdown]
# **Спасибо! Вы — человек — большой трудяга!**
#
# Успокоительный котобонус :)

# %% [markdown]
# ![photo_2025-01-17 15.20.31 (1).jpeg](data:image/jpeg;base64,...)
